# %%
import numpy as np
import pandas as pd
import matplotlib .pyplot as plt #importing info into graphs
# %matplotlib inline
import seaborn as sns

# %%
file1= pd.read_csv('/Users/hpb/Desktop/Ironhack week 2/mtcars.csv')

# %%
column_names=file1.columns

# %%
data=pd.DataFrame(columns=column_names)

# %%
data=pd.concat([data,file1],axis=0)

# %%
data.columns
# Out:
# Index(['Model', 'MPG', 'Cylinders', 'Displacement', 'Horsepower',
#        'Rear_Axle_Ratio', 'Weight (000)', 'Qtr_Mile_Time', 'Engine_Shape',
#        'Transmission', 'Fwd_Gears', 'Carburators'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Model               object
# MPG                float64
# Cylinders           object
# Displacement       float64
# Horsepower          object
# Rear_Axle_Ratio    float64
# Weight (000)       float64
# Qtr_Mile_Time      float64
# Engine_Shape        object
# Transmission        object
# Fwd_Gears           object
# Carburators         object
# dtype: object

# %%
sns.scatterplot(data=data, x="Horsepower", y="MPG", hue="MPG", size="MPG", sizes=(20,200), legend="full")
