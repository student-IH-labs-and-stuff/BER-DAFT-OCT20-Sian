# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df = pd.read_csv('/Users/felix/Documents/Ironhack/Course/Week_2/mtcars.csv')

# %%
df.describe()
# Out:
#              MPG  Cylinders  Displacement  Horsepower  Rear_Axle_Ratio  \
# count  32.000000  32.000000     32.000000   32.000000        32.000000
# mean   20.090625   6.187500    230.721875  146.687500         3.596563
# std     6.026948   1.785922    123.938694   68.562868         0.534679
# min    10.400000   4.000000     71.100000   52.000000         2.760000
# 25%    15.425000   4.000000    120.825000   96.500000         3.080000
# 50%    19.200000   6.000000    196.300000  123.000000         3.695000
# 75%    22.800000   8.000000    326.000000  180.000000         3.920000
# max    33.900000   8.000000    472.000000  335.000000         4.930000
#
#        Weight (000)  Qtr_Mile_Time  Engine_Shape  Transmission  Fwd_Gears  \
# count     32.000000      32.000000     32.000000     32.000000  32.000000
# mean       3.217250      17.848750      0.437500      0.406250   3.687500
# std        0.978457       1.786943      0.504016      0.498991   0.737804
# ...

# %%
plt.scatter(x=df['MPG'],y=df['Horsepower'])

# %%
x=df['MPG']
y=df['Horsepower']
stats.pearsonr(x,y)
# Out:
# (-0.7761683718265863, 1.7878352541210788e-07)

# %%
stats.kendalltau(x,y)
# Out:
# KendalltauResult(correlation=-0.7428125060886726, pvalue=4.331604948914874e-09)

# %%
MPGHP = df[['MPG', 'Horsepower',]]
correlations_matrix = MPGHP.corr()
correlations_matrix
# Out:
#                  MPG  Horsepower
# MPG         1.000000   -0.776168
# Horsepower -0.776168    1.000000

# %%
sns.heatmap(correlations_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
MPGCYL = df[['MPG', 'Cylinders',]]
correlations_matrix2 = MPGCYL.corr()
correlations_matrix2
# Out:
#                 MPG  Cylinders
# MPG        1.000000  -0.852162
# Cylinders -0.852162   1.000000

# %%
sns.heatmap(correlations_matrix2, annot=True)
# Out:
# <AxesSubplot:>

# %%
x=df['Cylinders']
y=df['MPG']
stats.pearsonr(x,y)
# Out:
# (-0.8521619594266132, 6.112687142580971e-10)

# %%
sns.pairplot(df)
