# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv('mtcars.csv')

# %%
data.head()
# Out:
#                Model   MPG  Cylinders  Displacement  Horsepower  \
# 0          Mazda RX4  21.0          6         160.0         110
# 1      Mazda RX4 Wag  21.0          6         160.0         110
# 2         Datsun 710  22.8          4         108.0          93
# 3     Hornet 4 Drive  21.4          6         258.0         110
# 4  Hornet Sportabout  18.7          8         360.0         175
#
#    Rear_Axle_Ratio  Weight (000)  Qtr_Mile_Time  Engine_Shape  Transmission  \
# 0             3.90         2.620          16.46             0             1
# 1             3.90         2.875          17.02             0             1
# 2             3.85         2.320          18.61             1             1
# 3             3.08         3.215          19.44             1             0
# 4             3.15         3.440          17.02             0             0
#
#    Fwd_Gears  Carburators
# 0          4            4
# 1          4            4
# 2          4            1
# ...

# %%
plt.scatter(x=data['MPG'],y= data['Horsepower'])

# %%
plt.scatter(x=data['Horsepower'],y= data['MPG'])

# %%
sns.scatterplot(data=data, x="MPG", y="Horsepower", hue= "Cylinders")

# %%
sns.scatterplot(data=data, x="MPG", y="Horsepower", hue= "Cylinders", palette= "BrBG")

# %%
sns.scatterplot(data=data, x= "Cylinders", y="Horsepower", hue= "MPG", palette= "BrBG")

# %%
data.shape
# Out:
# (32, 11)

# %%
data.dtypes
# Out:
# MPG                float64
# Cylinders            int64
# Displacement       float64
# Horsepower           int64
# Rear_Axle_Ratio    float64
# Weight (000)       float64
# Qtr_Mile_Time      float64
# Engine_Shape         int64
# Transmission         int64
# Fwd_Gears            int64
# Carburators          int64
# dtype: object

# %%
data.isna () #we have no missing values
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Rear_Axle_Ratio  Weight (000)  \
# 0   False      False         False       False            False         False
# 1   False      False         False       False            False         False
# 2   False      False         False       False            False         False
# 3   False      False         False       False            False         False
# 4   False      False         False       False            False         False
# 5   False      False         False       False            False         False
# 6   False      False         False       False            False         False
# 7   False      False         False       False            False         False
# 8   False      False         False       False            False         False
# 9   False      False         False       False            False         False
# 10  False      False         False       False            False         False
# ...

# %%
data = data.drop(['Model'], axis=1) # dropped it twice, therefore; the error. we dropeed the object type
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-2b3168ae80c0> in <module>
# ----> 1 data = data.drop(['Model'], axis=1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
corr_data = data
correlation_matrix = corr_data.corr()
correlation_matrix
# Out:
#                       MPG  Cylinders  Displacement  Horsepower  \
# MPG              1.000000  -0.852162     -0.847551   -0.776168
# Cylinders       -0.852162   1.000000      0.902033    0.832447
# Displacement    -0.847551   0.902033      1.000000    0.790949
# Horsepower      -0.776168   0.832447      0.790949    1.000000
# Rear_Axle_Ratio  0.681172  -0.699938     -0.710214   -0.448759
# Weight (000)    -0.867659   0.782496      0.887980    0.658748
# Qtr_Mile_Time    0.418684  -0.591242     -0.433698   -0.708223
# Engine_Shape     0.664039  -0.810812     -0.710416   -0.723097
# Transmission     0.599832  -0.522607     -0.591227   -0.243204
# Fwd_Gears        0.480285  -0.492687     -0.555569   -0.125704
# Carburators     -0.550925   0.526988      0.394977    0.749812
#
#                  Rear_Axle_Ratio  Weight (000)  Qtr_Mile_Time  Engine_Shape  \
# MPG                     0.681172     -0.867659       0.418684      0.664039
# ...

# %%
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
sns.regplot(x="MPG", y="Horsepower", data=data)
