# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(r'\Users\marcp\Desktop\Ironhack\Clases\Week 2\Day 1\2. Review Exercicie\mtcars.csv')

# %%
data.head()
# Out:
#                Model   MPG  Cylinders  Displacement  Horsepower  \
# 0          Mazda RX4  21.0          6         160.0         110
# 1      Mazda RX4 Wag  21.0          6         160.0         110
# 2         Datsun 710  22.8          4         108.0          93
# 3     Hornet 4 Drive  21.4          6         258.0         110
# 4  Hornet Sportabout  18.7          8         360.0         175
#
#    Rear_Axle_Ratio  Weight (000)  Qtr_Mile_Time  Engine_Shape  Transmission  \
# 0             3.90         2.620          16.46             0             1
# 1             3.90         2.875          17.02             0             1
# 2             3.85         2.320          18.61             1             1
# 3             3.08         3.215          19.44             1             0
# 4             3.15         3.440          17.02             0             0
#
#    Fwd_Gears  Carburators
# 0          4            4
# 1          4            4
# 2          4            1
# ...

# %%
#Generate a heat map between all variables
mask=np.zeros_like(data.corr())
mask[np.triu_indices_from(mask)]=True
fig, ax=plt.subplots(figsize=(10, 8))
ax=sns.heatmap(data.corr(), mask=mask, annot=True)
plt.show()

# %%
#Check correlation between MPG and horsepower
x = data['MPG']
y = data['Horsepower']
plt.scatter(x, y) 
plt.show()

#We see it's high correlated (-0.7), but have a negative correlation

# %%
#Check correlation between MPG and cylinders
x = data['MPG']
y = data['Cylinders']
plt.scatter(x, y) 
plt.show()

#We see it's high correlated, but have a negative correlation (-0.8). Our hypothesis it's wrong
