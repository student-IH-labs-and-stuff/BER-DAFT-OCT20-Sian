# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
file1 = pd.read_csv('/Users/rayanhawili/Desktop/IR_DAFT/Course/Day6/mtcars.csv')

# %%
file1.columns=[e.lower().replace(' ', '_') for e in file1.columns]

# %%
file1.head()
# Out:
#                model   mpg  cylinders  displacement  horsepower  \
# 0          Mazda RX4  21.0          6         160.0         110
# 1      Mazda RX4 Wag  21.0          6         160.0         110
# 2         Datsun 710  22.8          4         108.0          93
# 3     Hornet 4 Drive  21.4          6         258.0         110
# 4  Hornet Sportabout  18.7          8         360.0         175
#
#    rear_axle_ratio  weight_(000)  qtr_mile_time  engine_shape  transmission  \
# 0             3.90         2.620          16.46             0             1
# 1             3.90         2.875          17.02             0             1
# 2             3.85         2.320          18.61             1             1
# 3             3.08         3.215          19.44             1             0
# 4             3.15         3.440          17.02             0             0
#
#    fwd_gears  carburators
# 0          4            4
# 1          4            4
# 2          4            1
# ...

# %%
#1.hypothesis : MPG is ‘driven’ by horsepower
#(sub hypothesis … and is not affected by # cylinders)
#2. visualise it with seaborn / matplotlib
#3. share your code via slack or notebook on our class repo as plot_yourname_date

# %%
#sns.scatterplot(data=tips, x="total_bill", y="tip",hue="size",palette="CMRmap_r",size="size",sizes=(20,200),legend="full")

# %%
plt.scatter(x=file1['horsepower'],y=file1['mpg'])
#plt.title("mpg-horsepower relationship")
plt.xlabel("horsepower")
plt.ylabel("mpg")
# Out:
# Text(0, 0.5, 'mpg')

# %%
sns.scatterplot(data=file1, x="horsepower", y="mpg",hue="cylinders",palette="tab10",size="cylinders",sizes=(20,200),legend="full")

# %%
# mpg seems to be negatively correlater to horpower

# %%
file1.dtypes
# Out:
# model               object
# mpg                float64
# cylinders            int64
# displacement       float64
# horsepower           int64
# rear_axle_ratio    float64
# weight_(000)       float64
# qtr_mile_time      float64
# engine_shape         int64
# transmission         int64
# fwd_gears            int64
# carburators          int64
# dtype: object

# %%
data= file1.drop(['model'],axis=1)

# %%
data.dtypes
# Out:
# mpg                float64
# cylinders            int64
# displacement       float64
# horsepower           int64
# rear_axle_ratio    float64
# weight_(000)       float64
# qtr_mile_time      float64
# engine_shape         int64
# transmission         int64
# fwd_gears            int64
# carburators          int64
# dtype: object

# %%
correlations_matrix = data.corr()
mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %%
sns.regplot(x="horsepower",y="mpg",data=data)
