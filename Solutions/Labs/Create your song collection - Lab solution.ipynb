# %% [markdown]
# ### Lab: Create your collection of songs & audio features
#
# To move forward witht the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster.
#
# The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %% [markdown]
# ## Spotipy API
#
# Create an Spotify account and follow these steps to register an app: https://developer.spotify.com/documentation/general/guides/app-settings/
#
# After the app is created, you can see it on your dashboard
# https://developer.spotify.com/dashboard/applications
#
# Click on it and you'll find the client id and client secret.

# %% [markdown]
# #### Authentification

# %%
import spotipy # install if needed
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id="your-client-id",
    client_secret="your-client-secret"))

# %% [markdown]
# #### Pagination using "next"

# %% [markdown]
# When you collect songs from a playlist using `sp.playlist_tracks`, you're limited by the `limit` parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter `offset` allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function `sp.next()` does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key `next` on the results from any request.

# %%
tracks_from_playlist = sp.playlist_tracks("https://open.spotify.com/playlist/6uYt5DwcyaOxxPUundboC2")

# %%
# this is the link to the "next" page
next_page_link = tracks_from_playlist["next"]
next_page_link
# Out:
# 'https://api.spotify.com/v1/playlists/6uYt5DwcyaOxxPUundboC2/tracks?offset=100&limit=100&additional_types=track'

# %%
# this gives the full results directly
next_results = sp.next(tracks_from_playlist)
next_results
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/6uYt5DwcyaOxxPUundboC2/tracks?offset=100&limit=100&additional_types=track',
#  'items': [{'added_at': '2018-05-23T08:44:29Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/haeltotoe'},
#     'href': 'https://api.spotify.com/v1/users/haeltotoe',
#     'id': 'haeltotoe',
#     'type': 'user',
#     'uri': 'spotify:user:haeltotoe'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/79ZzC4nU2x7mRite0JZYkD'},
#      'href': 'https://api.spotify.com/v1/albums/79ZzC4nU2x7mRite0JZYkD',
#      'id': '79ZzC4nU2x7mRite0JZYkD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27312b5221825d6716ec1ee0414',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0212b5221825d6716ec1ee0414',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485112b5221825d6716ec1ee0414',
#        'width': 64}],
#      'name': 'Peaceville Presents... Rock / Prog',
#      'release_date': '2011-02-07',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:79ZzC4nU2x7mRite0JZYkD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5NXHXK6hOCotCF8lvGM1I0'},
#       'href': 'https://api.spotify.com/v1/artists/5NXHXK6hOCotCF8lvGM1I0',
#       'id': '5NXHXK6hOCotCF8lvGM1I0',
#       'name': 'Porcupine Tree',
#       'type': 'artist',
#       'uri': 'spotify:artist:5NXHXK6hOCotCF8lvGM1I0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 427746,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCQV0701049'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0oM3Bhw1U2FQVIuMIqint1'},
#     'href': 'https://api.spotify.com/v1/tracks/0oM3Bhw1U2FQVIuMIqint1',
#     'id': '0oM3Bhw1U2FQVIuMIqint1',
#     'is_local': False,
#     'name': 'Normal',
#     'popularity': 23,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a2c5cf2a30802fc6854183d2957f715906d341ba?cid=a7444f22ccd848f5ab52706a075c95cc',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0oM3Bhw1U2FQVIuMIqint1'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-05-23T08:44:49Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/haeltotoe'},
#     'href': 'https://api.spotify.com/v1/users/haeltotoe',
#     'id': 'haeltotoe',
#     'type': 'user',
#     'uri': 'spotify:user:haeltotoe'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#        'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#        'id': '4Z8W4fKeB5YxbusRsdQVPb',
#        'name': 'Radiohead',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7dxKtc08dYeRVHt3p9CZJn'},
#      'href': 'https://api.spotify.com/v1/albums/7dxKtc08dYeRVHt3p9CZJn',
#      'id': '7dxKtc08dYeRVHt3p9CZJn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273adb1732fa8d44b8eb2f6c0bf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02adb1732fa8d44b8eb2f6c0bf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851adb1732fa8d44b8eb2f6c0bf',
#        'width': 64}],
#      'name': 'OK Computer',
#      'release_date': '1997-05-28',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7dxKtc08dYeRVHt3p9CZJn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 299560,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE9701374'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4aOAzvRdOsZSwZIgwcdeL0'},
#     'href': 'https://api.spotify.com/v1/tracks/4aOAzvRdOsZSwZIgwcdeL0',
#     'id': '4aOAzvRdOsZSwZIgwcdeL0',
#     'is_local': False,
#     'name': 'Let Down',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/68c98db9439a6627ad6dc27e38072dc1e5015b2e?cid=a7444f22ccd848f5ab52706a075c95cc',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4aOAzvRdOsZSwZIgwcdeL0'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-05-23T08:45:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/haeltotoe'},
#     'href': 'https://api.spotify.com/v1/users/haeltotoe',
#     'id': 'haeltotoe',
#     'type': 'user',
#     'uri': 'spotify:user:haeltotoe'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#        'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#        'id': '1dfeR4HaWDbWqFHLkxsg1d',
#        'name': 'Queen',
#        'type': 'artist',
#        'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/21HMAUrbbYSj9NiPPlGumy'},
#      'href': 'https://api.spotify.com/v1/albums/21HMAUrbbYSj9NiPPlGumy',
#      'id': '21HMAUrbbYSj9NiPPlGumy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273008b06ec71019afd70153889',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02008b06ec71019afd70153889',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851008b06ec71019afd70153889',
#        'width': 64}],
#      'name': 'Jazz (Deluxe Remastered Version)',
#      'release_date': '1978-11-10',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:21HMAUrbbYSj9NiPPlGumy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#       'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#       'id': '1dfeR4HaWDbWqFHLkxsg1d',
#       'name': 'Queen',
#       'type': 'artist',
#       'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 209413,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71029610'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7hQJA50XrCWABAu5v6QZ4i'},
#     'href': 'https://api.spotify.com/v1/tracks/7hQJA50XrCWABAu5v6QZ4i',
#     'id': '7hQJA50XrCWABAu5v6QZ4i',
#     'is_local': False,
#     'name': "Don't Stop Me Now - Remastered 2011",
#     'popularity': 73,
#     'preview_url': None,
#     'track': True,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:7hQJA50XrCWABAu5v6QZ4i'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-05-23T08:45:21Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/haeltotoe'},
#     'href': 'https://api.spotify.com/v1/users/haeltotoe',
#     'id': 'haeltotoe',
#     'type': 'user',
#     'uri': 'spotify:user:haeltotoe'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22282KfMxDo2PMjnBc82I4'},
#        'href': 'https://api.spotify.com/v1/artists/22282KfMxDo2PMjnBc82I4',
#        'id': '22282KfMxDo2PMjnBc82I4',
#        'name': 'Biz Markie',
#        'type': 'artist',
#        'uri': 'spotify:artist:22282KfMxDo2PMjnBc82I4'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2OKf5WlgqFgszrDsxMq07t'},
#      'href': 'https://api.spotify.com/v1/albums/2OKf5WlgqFgszrDsxMq07t',
#      'id': '2OKf5WlgqFgszrDsxMq07t',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731960be23ca49f8e0639000ca',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021960be23ca49f8e0639000ca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511960be23ca49f8e0639000ca',
#        'width': 64}],
#      'name': "Biz's Baddest Beats: The Best of Biz Markie",
#      'release_date': '1994-08-07',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:2OKf5WlgqFgszrDsxMq07t'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22282KfMxDo2PMjnBc82I4'},
#       'href': 'https://api.spotify.com/v1/artists/22282KfMxDo2PMjnBc82I4',
#       'id': '22282KfMxDo2PMjnBc82I4',
#       'name': 'Biz Markie',
#       'type': 'artist',
#       'uri': 'spotify:artist:22282KfMxDo2PMjnBc82I4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 238266,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRH10902676'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3yNVfRQlUPViUh8O2V9SQn'},
#     'href': 'https://api.spotify.com/v1/tracks/3yNVfRQlUPViUh8O2V9SQn',
#     'id': '3yNVfRQlUPViUh8O2V9SQn',
#     'is_local': False,
#     'name': 'Just a Friend',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/666e175f61edc1a4e86d382f0de489302d8f9ddb?cid=a7444f22ccd848f5ab52706a075c95cc',
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:3yNVfRQlUPViUh8O2V9SQn'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-05-23T08:45:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/haeltotoe'},
#     'href': 'https://api.spotify.com/v1/users/haeltotoe',
#     'id': 'haeltotoe',
#     'type': 'user',
#     'uri': 'spotify:user:haeltotoe'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0k17h0D3J5VfsdmQ1iZtE9'},
#        'href': 'https://api.spotify.com/v1/artists/0k17h0D3J5VfsdmQ1iZtE9',
#        'id': '0k17h0D3J5VfsdmQ1iZtE9',
#        'name': 'Pink Floyd',
#        'type': 'artist',
#        'uri': 'spotify:artist:0k17h0D3J5VfsdmQ1iZtE9'}],
#      'available_markets': ['AE',
#       'AR',
#       'AU',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'DO',
#       'EC',
#       'EG',
#       'GT',
#       'HK',
#       'HN',
#       'ID',
#       'IL',
#       'IN',
#       'JO',
#       'KW',
#       'LB',
#       'MX',
#       'MY',
#       'NI',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PS',
#       'PY',
#       'QA',
#       'SA',
#       'SG',
#       'SV',
#       'TH',
#       'TN',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4xODvcpjOOgu4oKWL0sCte'},
#      'href': 'https://api.spotify.com/v1/albums/4xODvcpjOOgu4oKWL0sCte',
#      'id': '4xODvcpjOOgu4oKWL0sCte',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737a8c8bd7ee26fad509b79537',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027a8c8bd7ee26fad509b79537',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517a8c8bd7ee26fad509b79537',
#        'width': 64}],
#      'name': 'A Momentary Lapse of Reason',
#      'release_date': '1987-09-08',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4xODvcpjOOgu4oKWL0sCte'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0k17h0D3J5VfsdmQ1iZtE9'},
#       'href': 'https://api.spotify.com/v1/artists/0k17h0D3J5VfsdmQ1iZtE9',
#       'id': '0k17h0D3J5VfsdmQ1iZtE9',
#       'name': 'Pink Floyd',
#       'type': 'artist',
#       'uri': 'spotify:artist:0k17h0D3J5VfsdmQ1iZtE9'}],
#     'available_markets': ['AE',
#      'AR',
#      'AU',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'EG',
#      'GT',
#      'HK',
#      'HN',
#      'ID',
#      'IL',
#      'IN',
#      'JO',
#      'KW',
#      'LB',
#      'MX',
#      'MY',
#      'NI',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PS',
#      'PY',
#      'QA',
#      'SA',
#      'SG',
#      'SV',
#      'TH',
#      'TN',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 292080,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBN9X1100002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ieDOGcOqVxScs2VZBzidt'},
#     'href': 'https://api.spotify.com/v1/tracks/3ieDOGcOqVxScs2VZBzidt',
#     'id': '3ieDOGcOqVxScs2VZBzidt',
#     'is_local': False,
#     'name': 'Learning to Fly',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a5c5f66fd33b04c5c0c3ee947a5c2d2e5f208b6c?cid=a7444f22ccd848f5ab52706a075c95cc',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3ieDOGcOqVxScs2VZBzidt'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-05-23T08:45:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/haeltotoe'},
#     'href': 'https://api.spotify.com/v1/users/haeltotoe',
#     'id': 'haeltotoe',
#     'type': 'user',
#     'uri': 'spotify:user:haeltotoe'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jOstUTkEu2JkjvRdBA5Gu'},
#        'href': 'https://api.spotify.com/v1/artists/3jOstUTkEu2JkjvRdBA5Gu',
#        'id': '3jOstUTkEu2JkjvRdBA5Gu',
#        'name': 'Weezer',
#        'type': 'artist',
#        'uri': 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/33CmI2lR8PnQwz6133Mc7l'},
#      'href': 'https://api.spotify.com/v1/albums/33CmI2lR8PnQwz6133Mc7l',
#      'id': '33CmI2lR8PnQwz6133Mc7l',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273252c0cdd739400c558a753b2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02252c0cdd739400c558a753b2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851252c0cdd739400c558a753b2',
#        'width': 64}],
#      'name': 'Weezer (Deluxe Edition)',
#      'release_date': '1994-05-10',
#      'release_date_precision': 'day',
#      'total_tracks': 24,
#      'type': 'album',
#      'uri': 'spotify:album:33CmI2lR8PnQwz6133Mc7l'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jOstUTkEu2JkjvRdBA5Gu'},
#       'href': 'https://api.spotify.com/v1/artists/3jOstUTkEu2JkjvRdBA5Gu',
#       'id': '3jOstUTkEu2JkjvRdBA5Gu',
#       'name': 'Weezer',
#       'type': 'artist',
#       'uri': 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'}],
#     'available_markets': [],
#     'disc_number': 2,
#     'duration_ms': 256880,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USGF19962907'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4YPhn26bIFm2KUkL1VLzQG'},
#     'href': 'https://api.spotify.com/v1/tracks/4YPhn26bIFm2KUkL1VLzQG',
#     'id': '4YPhn26bIFm2KUkL1VLzQG',
#     'is_local': False,
#     'name': "Say It Ain't So",
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:4YPhn26bIFm2KUkL1VLzQG'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-05-23T08:46:12Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/haeltotoe'},
#     'href': 'https://api.spotify.com/v1/users/haeltotoe',
#     'id': 'haeltotoe',
#     'type': 'user',
#     'uri': 'spotify:user:haeltotoe'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#        'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#        'id': '3WrFJ7ztbogyGnTHbHJFl2',
#        'name': 'The Beatles',
#        'type': 'artist',
#        'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7vEJAtP3KgKSpOHVgwm3Eh'},
#      'href': 'https://api.spotify.com/v1/albums/7vEJAtP3KgKSpOHVgwm3Eh',
#      'id': '7vEJAtP3KgKSpOHVgwm3Eh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273582d56ce20fe0146ffa0e5cf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02582d56ce20fe0146ffa0e5cf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851582d56ce20fe0146ffa0e5cf',
#        'width': 64}],
#      'name': '1 (Remastered)',
#      'release_date': '2000-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:7vEJAtP3KgKSpOHVgwm3Eh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#       'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#       'id': '3WrFJ7ztbogyGnTHbHJFl2',
#       'name': 'The Beatles',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 425653,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71505902'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0aym2LBJBk9DAYuHHutrIl'},
#     'href': 'https://api.spotify.com/v1/tracks/0aym2LBJBk9DAYuHHutrIl',
#     'id': '0aym2LBJBk9DAYuHHutrIl',
#     'is_local': False,
#     'name': 'Hey Jude - Remastered 2015',
#     'popularity': 76,
#     'preview_url': None,
#     'track': True,
#     'track_number': 21,
#     'type': 'track',
#     'uri': 'spotify:track:0aym2LBJBk9DAYuHHutrIl'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-05-24T01:52:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/haeltotoe'},
#     'href': 'https://api.spotify.com/v1/users/haeltotoe',
#     'id': 'haeltotoe',
#     'type': 'user',
#     'uri': 'spotify:user:haeltotoe'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kACVPfCOnqzgfEF5ryl0x'},
#        'href': 'https://api.spotify.com/v1/artists/6kACVPfCOnqzgfEF5ryl0x',
#        'id': '6kACVPfCOnqzgfEF5ryl0x',
#        'name': 'Johnny Cash',
#        'type': 'artist',
#        'uri': 'spotify:artist:6kACVPfCOnqzgfEF5ryl0x'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2BlL4Gv2DLPu8p58Wcmlm9'},
#      'href': 'https://api.spotify.com/v1/albums/2BlL4Gv2DLPu8p58Wcmlm9',
#      'id': '2BlL4Gv2DLPu8p58Wcmlm9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736f4f62da3d811b6501a69ffa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026f4f62da3d811b6501a69ffa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516f4f62da3d811b6501a69ffa',
#        'width': 64}],
#      'name': 'American IV: The Man Comes Around',
#      'release_date': '2002-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:2BlL4Gv2DLPu8p58Wcmlm9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kACVPfCOnqzgfEF5ryl0x'},
#       'href': 'https://api.spotify.com/v1/artists/6kACVPfCOnqzgfEF5ryl0x',
#       'id': '6kACVPfCOnqzgfEF5ryl0x',
#       'name': 'Johnny Cash',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kACVPfCOnqzgfEF5ryl0x'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 216533,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USDJ20200650'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/28cnXtME493VX9NOw9cIUh'},
#     'href': 'https://api.spotify.com/v1/tracks/28cnXtME493VX9NOw9cIUh',
#     'id': '28cnXtME493VX9NOw9cIUh',
#     'is_local': False,
#     'name': 'Hurt',
#     'popularity': 76,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:28cnXtME493VX9NOw9cIUh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-05-24T02:20:16Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/haeltotoe'},
#     'href': 'https://api.spotify.com/v1/users/haeltotoe',
#     'id': 'haeltotoe',
#     'type': 'user',
#     'uri': 'spotify:user:haeltotoe'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ENzCHnmJUr20nUjoZ0zZ1'},
#        'href': 'https://api.spotify.com/v1/artists/7ENzCHnmJUr20nUjoZ0zZ1',
#        'id': '7ENzCHnmJUr20nUjoZ0zZ1',
#        'name': 'Snarky Puppy',
#        'type': 'artist',
#        'uri': 'spotify:artist:7ENzCHnmJUr20nUjoZ0zZ1'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4GzjQ0xXRlLl78ih481BUi'},
#      'href': 'https://api.spotify.com/v1/albums/4GzjQ0xXRlLl78ih481BUi',
#      'id': '4GzjQ0xXRlLl78ih481BUi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a29d1ada28cf3d9d5fe1972d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a29d1ada28cf3d9d5fe1972d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a29d1ada28cf3d9d5fe1972d',
#        'width': 64}],
#      'name': 'We Like It Here',
#      'release_date': '2014-02-25',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4GzjQ0xXRlLl78ih481BUi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ENzCHnmJUr20nUjoZ0zZ1'},
#       'href': 'https://api.spotify.com/v1/artists/7ENzCHnmJUr20nUjoZ0zZ1',
#       'id': '7ENzCHnmJUr20nUjoZ0zZ1',
#       'name': 'Snarky Puppy',
#       'type': 'artist',
#       'uri': 'spotify:artist:7ENzCHnmJUr20nUjoZ0zZ1'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 645720,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'US8JA1411008'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/68d6ZfyMUYURol2y15Ta2Y'},
#     'href': 'https://api.spotify.com/v1/tracks/68d6ZfyMUYURol2y15Ta2Y',
#     'id': '68d6ZfyMUYURol2y15Ta2Y',
#     'is_local': False,
#     'name': 'Lingus',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/da065def642a98be2ae5e5d40c423490b40cd74d?cid=a7444f22ccd848f5ab52706a075c95cc',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:68d6ZfyMUYURol2y15Ta2Y'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-05-24T19:37:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/haeltotoe'},
#     'href': 'https://api.spotify.com/v1/users/haeltotoe',
#     'id': 'haeltotoe',
#     'type': 'user',
#     'uri': 'spotify:user:haeltotoe'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0IG2IHSZTxnFOxitXi5cyE'},
#        'href': 'https://api.spotify.com/v1/artists/0IG2IHSZTxnFOxitXi5cyE',
#        'id': '0IG2IHSZTxnFOxitXi5cyE',
#        'name': 'Madd',
#        'type': 'artist',
#        'uri': 'spotify:artist:0IG2IHSZTxnFOxitXi5cyE'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2dbeL5Qam5MxrMV3uWZwEu'},
#      'href': 'https://api.spotify.com/v1/albums/2dbeL5Qam5MxrMV3uWZwEu',
#      'id': '2dbeL5Qam5MxrMV3uWZwEu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273966ec203d7d111609b83e98c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02966ec203d7d111609b83e98c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851966ec203d7d111609b83e98c',
#        'width': 64}],
#      'name': 'Q.E.D.',
#      'release_date': '2016-12-06',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2dbeL5Qam5MxrMV3uWZwEu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0IG2IHSZTxnFOxitXi5cyE'},
#       'href': 'https://api.spotify.com/v1/artists/0IG2IHSZTxnFOxitXi5cyE',
#       'id': '0IG2IHSZTxnFOxitXi5cyE',
#       'name': 'Madd',
#       'type': 'artist',
#       'uri': 'spotify:artist:0IG2IHSZTxnFOxitXi5cyE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 92746,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMEU31618951'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6U1nomSXLDtNYKLsnhrpd7'},
#     'href': 'https://api.spotify.com/v1/tracks/6U1nomSXLDtNYKLsnhrpd7',
#     'id': '6U1nomSXLDtNYKLsnhrpd7',
#     'is_local': False,
#     'name': 'Nimrod',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6361092e3948c036cd396c6e7303133943bd8f2d?cid=a7444f22ccd848f5ab52706a075c95cc',
#     'track': True,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:6U1nomSXLDtNYKLsnhrpd7'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-07-03T05:32:02Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/haeltotoe'},
#     'href': 'https://api.spotify.com/v1/users/haeltotoe',
#     'id': 'haeltotoe',
#     'type': 'user',
#     'uri': 'spotify:user:haeltotoe'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0IG2IHSZTxnFOxitXi5cyE'},
#        'href': 'https://api.spotify.com/v1/artists/0IG2IHSZTxnFOxitXi5cyE',
#        'id': '0IG2IHSZTxnFOxitXi5cyE',
#        'name': 'Madd',
#        'type': 'artist',
#        'uri': 'spotify:artist:0IG2IHSZTxnFOxitXi5cyE'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7o147EDa1Vm5Odif8HQdM0'},
#      'href': 'https://api.spotify.com/v1/albums/7o147EDa1Vm5Odif8HQdM0',
#      'id': '7o147EDa1Vm5Odif8HQdM0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d6a4a4a69cccc5eaa336550d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d6a4a4a69cccc5eaa336550d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d6a4a4a69cccc5eaa336550d',
#        'width': 64}],
#      'name': 'One More Hour',
#      'release_date': '2018-07-02',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7o147EDa1Vm5Odif8HQdM0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0IG2IHSZTxnFOxitXi5cyE'},
#       'href': 'https://api.spotify.com/v1/artists/0IG2IHSZTxnFOxitXi5cyE',
#       'id': '0IG2IHSZTxnFOxitXi5cyE',
#       'name': 'Madd',
#       'type': 'artist',
#       'uri': 'spotify:artist:0IG2IHSZTxnFOxitXi5cyE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 148394,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ushm21856947'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2GraM64XsB6VRnGGvgZ4OH'},
#     'href': 'https://api.spotify.com/v1/tracks/2GraM64XsB6VRnGGvgZ4OH',
#     'id': '2GraM64XsB6VRnGGvgZ4OH',
#     'is_local': False,
#     'name': 'Vexed Milieu',
#     'popularity': 7,
#     'preview_url': 'https://p.scdn.co/mp3-preview/806f8722082a6ab7278105e8aebc679537ad4153?cid=a7444f22ccd848f5ab52706a075c95cc',
#     'track': True,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:2GraM64XsB6VRnGGvgZ4OH'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 100,
#  'previous': 'https://api.spotify.com/v1/playlists/6uYt5DwcyaOxxPUundboC2/tracks?offset=0&limit=100&additional_types=track',
#  'total': 111}

# %%
# this playlist has 111 songs, so there's no 3rt page:
print(sp.next(next_results))
print(next_results["next"])
# Out:
# None
# None

# %% [markdown]
#  ## Sample lab solution

# %% [markdown]
# #### Step 1: get uris of all the songs in a playlist (no matter how many songs the playlist has)

# %%
def get_tracks_ids_from_playlist(playlist_id):
    
    final_results = []
    result = sp.playlist_tracks(playlist_id)
    final_results.extend(result["items"])
    
    while result["next"]:
        
        result = sp.next(result)
        final_results.extend(result["items"])
        
    ids = [track["track"]["id"] for track in final_results]
    
    # we return only values that are not None:
    return [i for i in ids if i]

# %%
get_tracks_ids_from_playlist("https://open.spotify.com/playlist/6uYt5DwcyaOxxPUundboC2")
# Out:
# ['74X1epeRufHckhuX1KFD04',
#  '1QEEqeFIZktqIpPI4jSVSF',
#  '6m4HWTYMRSJkaUuvXTaNmE',
#  '2WfaOiMkCvy7F5fcp2zZ8L',
#  '0sDqo9UPzPUtu9wEkI3zRB',
#  '67Hna13dNDkZvBpTXRIaOJ',
#  '2X485T9Z5Ly0xyaghN73ed',
#  '1KDsONFxp3YtnJTaLeWFIi',
#  '5AhDb4oM6f4YmHPXW123Fg',
#  '6cr6UDpkjEaMQ80OjWqEBQ',
#  '7E1boGBVKRPqbHuEDXXZ7D',
#  '3MODES4TNtygekLl146Dxd',
#  '131yybV7A3TmC34a0qE8u8',
#  '2LkaNhCrNVmcYgXJeLVmsw',
#  '05f8Hg3RSfiPSCBQOtxl3i',
#  '3gdewACMIVMEWVbyb8O9sY',
#  '5dRwQffP46e2zNsBiEEJ9P',
#  '70gbuMqwNBE2Y5rkQJE9By',
#  '28VC9MNZSJZOqiAHUU8XSP',
#  '38Ngied9rBORlAbLYNCl4k',
#  '6pnwfWyaWjQiHCKTiZLItr',
#  '2nVHqZbOGkKWzlcy1aMbE7',
#  '7BY005dacJkbO6EPiOh2wb',
#  '5ihS6UUlyQAfmp48eSkxuQ',
#  '1lFC3sMgOcDrVzNh8zXRnl',
#  '0hKRSZhUGEhKU6aNSPBACZ',
#  '0YveezON7jpiaHA8fnUHxN',
#  '6aBUnkXuCEQQHAlTokv9or',
#  '6mcxQ1Y3uQRU0IHsvdNLH1',
#  '3TO7bbrUKrOSPGRTB5MeCz',
#  '7qL6WYHu1148Y58bhgFZC2',
#  '72Z17vmmeQKAg8bptWvpVG',
#  '7Jh1bpe76CNTCgdgAdBw4Z',
#  '3FCto7hnn1shUyZL42YgfO',
#  '57zJeqbOA6AHsv2n6BMcm6',
#  '1ju7EsSGvRybSNEsRvc7qY',
#  '2QVmiA93GVhWNTWQctyY1K',
#  '6ZSTinOwx5dKFYc6iYyGDn',
#  '4vpeKl0vMGdAXpZiQB2Dtd',
#  '2CPturRUlpvirYr7VpkXCV',
#  '1iDcKYNvo6gglrOG6lvnHL',
#  '5QTxFnGygVM4jFQiBovmRo',
#  '0ofHAoxe9vBkTCp2UQIavz',
#  '6vrUTGn5p8IrfTZ0J6sIVM',
#  '2374M0fQpWi3dLnB54qaLX',
#  '52vA3CYKZqZVdQnzRrdZt6',
#  '3d9DChrdc6BOeFsbrZ3Is0',
#  '4iCGSi1RonREsPtfEKYj5b',
#  '3ZE3wv8V3w2T2f7nOCjV0N',
#  '3KNPVCidUvKR5qVmXv1rEi',
#  '63T7DJ1AFDD6Bn8VzG6JE8',
#  '5e9TFTbltYBg2xThimr0rU',
#  '3SdTKo2uVsxFblQjpScoHy',
#  '01SfTM5nfCou5gQL70r6gs',
#  '5eZrW59C3UgBhkqNlowEID',
#  '5aHHf6jrqDRb1fcBmue2kn',
#  '69pwmeyvQMuHMtkCmpEWhQ',
#  '5AVLNm62sG9axDJ9Mkl5g8',
#  '56Z7hbyMrndw1naxb6I5Oi',
#  '5EWPGh7jbTNO2wakv8LjUI',
#  '2M9ro2krNb7nr7HSprkEgo',
#  '0b9d9bLTymAIo605NyUZvi',
#  '78lgmZwycJ3nzsdgmPPGNx',
#  '6mFkJmJqdDVQ1REhVfGgd1',
#  '5qdfWEpY1sp9ECXWcUJOpR',
#  '7DsaOo87BUgyNwMxD6nhC9',
#  '2x7SSiqsxCC3Qm1GIRyNtv',
#  '3q2v8QaTnHLveAQzR6gvYm',
#  '4Iyo50UoYhuuYORMLrGDci',
#  '4Gk6ZOiSsI4gt1X8A9y9b7',
#  '57iDDD9N9tTWe75x6qhStw',
#  '26tWBbtjvgi0tipRL2VQ2X',
#  '3krl7sINykINxFRBkt05HN',
#  '7wrid74YIxL3YilXHYIfjQ',
#  '4MZEZz8MqVgvIMXU6AVP22',
#  '10HlI5OL8VIdMh2CaymhbD',
#  '2PpruBYCo4H7WOBJ7Q2EwM',
#  '0aSM7UdzJKJELt4srUuoo8',
#  '7ivFPfl00gNbqWiVnEyEMv',
#  '1T4iwEA2ySieXjWxjiMVWs',
#  '4RaxnzmTN4bojbbEYtvXjk',
#  '4p82pfEa4cayPqXLN6Rhzm',
#  '389QX9Q1eUOEZ19vtzzI9O',
#  '5UWwZ5lm5PKu6eKsHAGxOk',
#  '125sShtsY0PMA5aBuytNaQ',
#  '18AXbzPzBS8Y3AkgSxzJPb',
#  '2cbic3TiUENlJX91y67ARR',
#  '0d28khcov6AiegSCpG5TuT',
#  '5CQ30WqJwcep0pYcV4AMNc',
#  '1GqlvSEtMx5xbGptxOTTyk',
#  '2QgWuCtBpNIpl5trmKCxRf',
#  '7KA6U0WOHdGxWWLGPYN2Sb',
#  '1hE3nUTjZLhOIr0KFCOfDe',
#  '5eCytMYwGJDOh20KsZYaum',
#  '7d6wbpTrjaMt94nIcV1pnZ',
#  '6lFZbCc7pn6Lme1NP7qQqQ',
#  '72ccSGl5YcEWm0vhtVpi25',
#  '0ll8uFnc0nANY35E0Lfxvg',
#  '0xtXgzWYvjdQnnmO8iLHsa',
#  '01ZpFhrMMqKPVCwyqXneVp',
#  '0oM3Bhw1U2FQVIuMIqint1',
#  '4aOAzvRdOsZSwZIgwcdeL0',
#  '7hQJA50XrCWABAu5v6QZ4i',
#  '3yNVfRQlUPViUh8O2V9SQn',
#  '3ieDOGcOqVxScs2VZBzidt',
#  '4YPhn26bIFm2KUkL1VLzQG',
#  '0aym2LBJBk9DAYuHHutrIl',
#  '28cnXtME493VX9NOw9cIUh',
#  '68d6ZfyMUYURol2y15Ta2Y',
#  '6U1nomSXLDtNYKLsnhrpd7',
#  '2GraM64XsB6VRnGGvgZ4OH']

# %% [markdown]
# #### Step 2: build a df with all the audio features

# %%
# we're gonna iterate through the output of the function above
sp.audio_features(track_ids[0])[0]
# Out:
# [{'danceability': 0.339,
#   'energy': 0.143,
#   'key': 0,
#   'loudness': -10.78,
#   'mode': 1,
#   'speechiness': 0.0317,
#   'acousticness': 0.921,
#   'instrumentalness': 0.000636,
#   'liveness': 0.372,
#   'valence': 0.0948,
#   'tempo': 101.213,
#   'type': 'audio_features',
#   'id': '74X1epeRufHckhuX1KFD04',
#   'uri': 'spotify:track:74X1epeRufHckhuX1KFD04',
#   'track_href': 'https://api.spotify.com/v1/tracks/74X1epeRufHckhuX1KFD04',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/74X1epeRufHckhuX1KFD04',
#   'duration_ms': 413320,
#   'time_signature': 3}]

# %%
def get_audio_features_df(playlist_id):
    track_ids = get_tracks_ids_from_playlist(playlist_id)
    aud_feat = [sp.audio_features(track)[0] for track in track_ids]
    return pd.DataFrame(aud_feat)

# %%
audio_f = get_audio_features_df("https://open.spotify.com/playlist/6uYt5DwcyaOxxPUundboC2")
audio_f.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.339   0.143    0   -10.780     1       0.0317      0.921000
# 1         0.377   0.682    7    -8.039     1       0.0299      0.000894
# 2         0.138   0.712    0    -5.271     1       0.0690      0.746000
# 3         0.573   0.902    6    -7.638     0       0.0540      0.018000
# 4         0.630   0.519    9   -10.997     1       0.0528      0.225000
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000636    0.3720   0.0948  101.213  audio_features
# 1          0.002170    0.0504   0.2880  108.736  audio_features
# 2          0.773000    0.0714   0.1330   99.877  audio_features
# 3          0.001250    0.0928   0.8760   84.412  audio_features
# 4          0.000004    0.0974   0.5020  143.942  audio_features
#
#                        id                                   uri  \
# 0  74X1epeRufHckhuX1KFD04  spotify:track:74X1epeRufHckhuX1KFD04
# 1  1QEEqeFIZktqIpPI4jSVSF  spotify:track:1QEEqeFIZktqIpPI4jSVSF
# 2  6m4HWTYMRSJkaUuvXTaNmE  spotify:track:6m4HWTYMRSJkaUuvXTaNmE
# 3  2WfaOiMkCvy7F5fcp2zZ8L  spotify:track:2WfaOiMkCvy7F5fcp2zZ8L
# 4  0sDqo9UPzPUtu9wEkI3zRB  spotify:track:0sDqo9UPzPUtu9wEkI3zRB
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/74X1epeRufHc...
# 1  https://api.spotify.com/v1/tracks/1QEEqeFIZktq...
# 2  https://api.spotify.com/v1/tracks/6m4HWTYMRSJk...
# 3  https://api.spotify.com/v1/tracks/2WfaOiMkCvy7...
# 4  https://api.spotify.com/v1/tracks/0sDqo9UPzPUt...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/74X1...       413320
# 1  https://api.spotify.com/v1/audio-analysis/1QEE...       285133
# 2  https://api.spotify.com/v1/audio-analysis/6m4H...       203067
# 3  https://api.spotify.com/v1/audio-analysis/2Wfa...       225280
# 4  https://api.spotify.com/v1/audio-analysis/0sDq...       278627
#
#    time_signature
# 0               3
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# #### Step 3: grow the df with multiple playlists

# %%
playlists = ["https://open.spotify.com/playlist/2FaOyGU5gIiwDpck5Ui7L9",
             "https://open.spotify.com/playlist/10h9MYW9lIRp31fawvmjE8",
             "https://open.spotify.com/playlist/3YdCzysSu8jLNYXYaheZAF",
             "https://open.spotify.com/playlist/6IfGK9nLC9ChgD7FTZzkLJ"]

# %%
def get_big_audio_df(playlists_list):
    audio_f_df = pd.DataFrame()
    
    for p in playlists_list:
        audio_f_df = audio_f_df.append(get_audio_features_df(p))

    return audio_f_df

# %%
big_df_songs_audiofeat = get_big_audio_df(playlists)

# %%
big_df_songs_audiofeat
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.658  0.2590   11   -13.141     0       0.0705       0.69400
# 1           0.742  0.3990    2   -12.646     1       0.0346       0.21700
# 2           0.851  0.7300    2   -11.048     1       0.3470       0.45300
# 3           0.705  0.0502    4   -18.115     1       0.0471       0.87900
# 4           0.651  0.1190    6   -19.807     1       0.0380       0.91600
# ..            ...     ...  ...       ...   ...          ...           ...
# 218         0.617  0.5670    0    -4.188     1       0.0828       0.05840
# 219         0.608  0.5360    8    -5.355     0       0.0469       0.00704
# 220         0.541  0.7910    4    -4.183     1       0.2230       0.05390
# 221         0.501  0.6740    5    -6.363     1       0.0408       0.00346
# 222         0.754  0.5830    4    -7.340     0       0.0432       0.32000
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000059    0.9750    0.306  110.376  audio_features
# 1            0.000002    0.1070    0.693  125.039  audio_features
# 2            0.000063    0.1240    0.905   93.698  audio_features
# 3            0.000041    0.3860    0.524  106.802  audio_features
# 4            0.000343    0.1040    0.402  120.941  audio_features
# ..                ...       ...      ...      ...             ...
# 218          0.000000    0.0933    0.505   90.246  audio_features
# 219          0.000036    0.4600    0.167  112.035  audio_features
# 220          0.000000    0.1100    0.314  105.792  audio_features
# 221          0.000036    0.2820    0.152  155.051  audio_features
# 222          0.000150    0.1440    0.770  122.012  audio_features
#
#                          id                                   uri  \
# 0    1n7JnwviZ7zf0LR1tcGFq7  spotify:track:1n7JnwviZ7zf0LR1tcGFq7
# 1    5QGM1U0eCYrQuwSJwTm5Zq  spotify:track:5QGM1U0eCYrQuwSJwTm5Zq
# 2    0NLIFSZxPzQhCwnkn5PJYs  spotify:track:0NLIFSZxPzQhCwnkn5PJYs
# 3    3mXqOdlLE1k67WsAxryPFs  spotify:track:3mXqOdlLE1k67WsAxryPFs
# 4    7bSzjzjTkWT2CkIPPdp0eA  spotify:track:7bSzjzjTkWT2CkIPPdp0eA
# ..                      ...                                   ...
# 218  1CnPYaKxTVb4LWOtiGOm0m  spotify:track:1CnPYaKxTVb4LWOtiGOm0m
# 219  1bjd4UgjnK5hedJJKmi3YP  spotify:track:1bjd4UgjnK5hedJJKmi3YP
# 220  2B5uUYyiDpFCgEGdbVpOZj  spotify:track:2B5uUYyiDpFCgEGdbVpOZj
# 221  1fipvP2zmef6vN2IwXfJhY  spotify:track:1fipvP2zmef6vN2IwXfJhY
# 222  6xZ4Q2k2ompmDppyeESIY8  spotify:track:6xZ4Q2k2ompmDppyeESIY8
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/1n7JnwviZ7zf...
# 1    https://api.spotify.com/v1/tracks/5QGM1U0eCYrQ...
# 2    https://api.spotify.com/v1/tracks/0NLIFSZxPzQh...
# 3    https://api.spotify.com/v1/tracks/3mXqOdlLE1k6...
# 4    https://api.spotify.com/v1/tracks/7bSzjzjTkWT2...
# ..                                                 ...
# 218  https://api.spotify.com/v1/tracks/1CnPYaKxTVb4...
# 219  https://api.spotify.com/v1/tracks/1bjd4UgjnK5h...
# 220  https://api.spotify.com/v1/tracks/2B5uUYyiDpFC...
# 221  https://api.spotify.com/v1/tracks/1fipvP2zmef6...
# 222  https://api.spotify.com/v1/tracks/6xZ4Q2k2ompm...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/1n7J...       256213
# 1    https://api.spotify.com/v1/audio-analysis/5QGM...       191867
# 2    https://api.spotify.com/v1/audio-analysis/0NLI...       152267
# 3    https://api.spotify.com/v1/audio-analysis/3mXq...       186227
# 4    https://api.spotify.com/v1/audio-analysis/7bSz...       273680
# ..                                                 ...          ...
# 218  https://api.spotify.com/v1/audio-analysis/1CnP...       217603
# 219  https://api.spotify.com/v1/audio-analysis/1bjd...       203841
# 220  https://api.spotify.com/v1/audio-analysis/2B5u...       208474
# 221  https://api.spotify.com/v1/audio-analysis/1fip...       200838
# 222  https://api.spotify.com/v1/audio-analysis/6xZ4...       220051
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 218               4
# 219               4
# 220               4
# 221               4
# 222               4
#
# [716 rows x 18 columns]

# %% [markdown]
# Disclaimer: when Spotify's API takes more than 5 seconds to respond, it gives a Time readout error - ideally we'd use try - except to circumvent that. It can be in our next iteration!
