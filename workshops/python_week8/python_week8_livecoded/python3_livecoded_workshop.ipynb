# %%
ls

# %% [markdown]
# Please install into your environment
# ```bash
# conda install -c conda-forge pandas-profiling
# ```

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas_profiling

# %%
ls
# Out:
# data/        ml_for_my_final_projectr/  python3_livecoded_workshop.ipynb
# evaluate.py  __pycache__/

# %%
df_train = pd.read_csv("data/train.csv")
df_test = pd.read_csv("data/test.csv")

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df = pd.concat([df_train, df_test], axis=0).reset_index(drop=True)
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
df['Fare'].value_counts()
# Out:
# 8.0500     60
# 13.0000    59
# 7.7500     55
# 26.0000    50
# 7.8958     49
#            ..
# 33.5000     1
# 7.8000      1
# 26.3875     1
# 15.5792     1
# 7.1417      1
# Name: Fare, Length: 281, dtype: int64

# %%
# df.profile_report()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = pd.get_dummies(df, columns=['Sex'], drop_first=True)

# %%
df = df.rename(columns={'Sex_male':'is_male'})

# %%
df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# is_male           0
# dtype: int64

# %%
df = df.dropna(subset=['Survived', 'Age'])

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         2
# is_male          0
# dtype: int64

# %%
df['Survived'].value_counts().to_frame()
# Out:
#      Survived
# 0.0       424
# 1.0       290

# %%
df_ml = df[['SibSp','Parch','Pclass','Fare','Age', 'Survived', 'is_male']]

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()

# %%
X_res, y_res = sm.fit_resample(df_ml.drop(columns=['Survived']), df_ml['Survived'])

# %%
df_ml = pd.concat([X_res, y_res], axis=1)

# %%
df_ml
# Out:
#      SibSp  Parch  Pclass       Fare        Age  is_male  Survived
# 0        1      0       3   7.250000  22.000000        1       0.0
# 1        1      0       1  71.283300  38.000000        0       1.0
# 2        0      0       3   7.925000  26.000000        0       1.0
# 3        1      0       1  53.100000  35.000000        0       1.0
# 4        0      0       3   8.050000  35.000000        1       0.0
# ..     ...    ...     ...        ...        ...      ...       ...
# 843      1      0       1  56.119414  51.340066        0       1.0
# 844      1      0       2  26.000000  28.476903        0       1.0
# 845      0      0       2  12.352647  30.008144        0       1.0
# 846      0      0       2  24.308640  27.537039        0       1.0
# 847      0      0       1  30.812121  28.872725        0       1.0
#
# [848 rows x 7 columns]

# %%
df_ml['Survived'].value_counts()
# Out:
# 1.0    424
# 0.0    424
# Name: Survived, dtype: int64

# %% [markdown]
# # 2. Machine Learning / Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
X = sc.fit_transform(df_ml.drop('Survived', axis=1))
y = df_ml['Survived']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import plot_confusion_matrix, classification_report, accuracy_score

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
pred = rfc.predict(X_test)
print(classification_report(y_test, pred))
print(accuracy_score(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.82      0.83       141
#          1.0       0.83      0.85      0.84       139
#
#     accuracy                           0.84       280
#    macro avg       0.84      0.84      0.84       280
# weighted avg       0.84      0.84      0.84       280
#
# 0.8357142857142857

# %%
disp = plot_confusion_matrix(rfc, X_test, y_test,
                     display_labels= ["Not survived", 'Survived'])

disp.ax_.set_title("Confusion Matrix \n Random Forest")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix \n Random Forest')

# %%
df_train = pd.read_csv("data/train.csv")
df_test = pd.read_csv("data/test.csv")
df = pd.concat([df_train, df_test], axis=0).reset_index(drop=True)

# %%
# Again dropping rows where survived or age equal nan.
df = df.dropna(subset=['Survived', 'Age'])

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         2
# dtype: int64

# %% [markdown]
# ### [parenthesis] List comprehensions and dict comprehensions, how to?

# %% [markdown]
# ```python
#
# {column_name:column_name.lower().replace(" ", "_") }
#
# ```

# %%
[x**2 for x in [1,2,3,4]]
# Out:
# [1, 4, 9, 16]

# %%
{k:int(k)**2 for k in ['1', '2', '4', '7']}
# Out:
# {'1': 1, '2': 4, '4': 16, '7': 49}

# %%
{column:column.lower().replace(" ", "_") for column in df.columns}
# Out:
# {'PassengerId': 'passengerid',
#  'Survived': 'survived',
#  'Pclass': 'pclass',
#  'Name': 'name',
#  'Sex': 'sex',
#  'Age': 'age',
#  'SibSp': 'sibsp',
#  'Parch': 'parch',
#  'Ticket': 'ticket',
#  'Fare': 'fare',
#  'Cabin': 'cabin',
#  'Embarked': 'embarked'}

# %%
df = df.rename(columns={column:column.lower().replace(" ", "_") for column in df.columns})

# %%
df
# Out:
#      passengerid  survived  pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 885          886       0.0       3
# 886          887       0.0       2
# 887          888       1.0       1
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['name'].apply(lambda x: x.split(", ")[1].split()[0]).value_counts()
# Out:
# Mr.          398
# Miss.        146
# Mrs.         108
# Master.       36
# Dr.            6
# Rev.           6
# Mlle.          2
# Col.           2
# Major.         2
# Jonkheer.      1
# Capt.          1
# the            1
# Mme.           1
# Ms.            1
# Lady.          1
# Don.           1
# Sir.           1
# Name: name, dtype: int64

# %%
'Braund, Mr. Owen Harris'.split(' ')[1]
# Out:
# 'Mr.'

# %% [markdown]
# is_mr | is_mrs
# -------|-------
# 1|0
# 0|1
# 0|1

# %%
df['is_mr'] = df['name'].apply(lambda x: int('Mr.' in x))

# %%
translate_dct = {'is_mrs':'Mrs.',
                'is_mr':'Mr.',
                'is_miss':'Miss',
                'is_rev':'Rev.',
                'is_master':'Master.',
                'is_dr':'Dr.',
                }
for new_col, keyword in translate_dct.items():
    df[new_col] = df['name'].apply(lambda x: int(keyword in x))

# %%
df
# Out:
#      passengerid  survived  pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 885          886       0.0       3
# 886          887       0.0       2
# 887          888       1.0       1
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.get_dummies(df, columns=['sex'], drop_first=True)

# %%
df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 name   age  sibsp  parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              ticket     fare cabin embarked  is_mr  is_mrs  is_miss  is_rev  \
# 0         A/5 21171   7.2500   NaN        S      1       0        0       0
# 1          PC 17599  71.2833   C85        C      0       1        0       0
# 2  STON/O2. 3101282   7.9250   NaN        S      0       0        1       0
# ...

# %%
df_ml = df[[
    'sex_male',
    'sibsp',
    'parch',
    'pclass',
    'fare',
    'age',
    'survived',
    'is_mrs',
    'is_miss',
    'is_mr',
    'is_rev',
    'is_master',
    'is_dr',
]]

# %%
sc = StandardScaler()
X = sc.fit_transform(df_ml.drop('survived', axis=1))
y = df_ml['survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=17)

rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
pred = rfc.predict(X_test)
print(classification_report(y_test, pred))
print(accuracy_score(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.86      0.86       146
#          1.0       0.77      0.76      0.76        90
#
#     accuracy                           0.82       236
#    macro avg       0.81      0.81      0.81       236
# weighted avg       0.82      0.82      0.82       236
#
# 0.8220338983050848

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

cls_lst = [KNeighborsClassifier(),
          SVC(),
          GaussianProcessClassifier(),
          DecisionTreeClassifier(),
          RandomForestClassifier(),
          AdaBoostClassifier(),
          GaussianNB(),
          QuadraticDiscriminantAnalysis(),
          ]

def evaluate(df, cls):
    accuracies = {}
    
    for cl in cls:
        sc = StandardScaler()
        X = sc.fit_transform(df_ml.drop('survived', axis=1))
        y = df_ml['survived']

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=17)

        
        cl.fit(X_train, y_train)
        pred = cl.predict(X_test)
        # print(classification_report(y_test, pred))
        accuracies[cl.__class__.__name__] = accuracy_score(y_test, pred)
        #print(accuracy_score(y_test, pred))
    return accuracies

accuracy_dict = evaluate(df_ml, cls_lst)


accuracy_df = pd.DataFrame(accuracy_dict, index=[0])
# Out:
# /home/flo/anaconda3/envs/ironhack/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
my_classifier = KNeighborsClassifier()

# %%
my_classifier.__class__.__name__
# Out:
# 'KNeighborsClassifier'

# %% [markdown]
# What I want: A dictionary that looks like this:
# ```python
# {<classfier_name>:<accuracy score>}
# ```

# %%
accuracy_df.plot(kind='bar', legend=False)
# Out:
# <AxesSubplot:>

# %%
accuracy_df.T.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
from evaluate import evaluate

# %%
from ml_for_my_final_project.evaluate import evaluate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-56-587e30f66cb3> in <module>
# ----> 1 from ml_for_my_final_project.evaluate import evaluate
#
# ModuleNotFoundError: No module named 'ml_for_my_final_project'
