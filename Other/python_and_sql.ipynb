# %% [markdown]
# # Lesson 1 Key Concepts

# %% [markdown]
# ## Importing libraries

# %%
from sqlalchemy import create_engine
import pandas as pd
import getpass  # To get the password without showing the input
password = getpass.getpass()
# Out:
# ········

# %% [markdown]
# ## Establishing the connection with MySQL

# %%
# this is the general syntax 'dialect+driver://username:password@host:port/database'
# to create the connection string

connection_string = 'mysql+pymysql://root:' + password + '@localhost/bank'
engine = create_engine(connection_string)
data = pd.read_sql_query('SELECT * FROM bank.loan', engine)
data.head()
# Out:
#    loan_id  account_id    date  amount  duration  payments status  \
# 0     5314        1787  930705   96396        12    8033.0      B
# 1     5316        1801  930711  165960        36    4610.0      A
# 2     6863        9188  930728  127080        60    2118.0      A
# 3     5325        1843  930803  105804        36    2939.0      A
# 4     7240       11013  930906  274740        60    4579.0      A
#
#                      status_desc
# 0  Defaulter - Contract Finished
# 1       Good - Contract Finished
# 2       Good - Contract Finished
# 3       Good - Contract Finished
# 4       Good - Contract Finished

# %% [markdown]
# ## Using engine object with executable class

# %%
result = engine.execute('SELECT * FROM bank.loan')
for row in result:
    print(row)

rows = [row for row in result]
pd.DataFrame(rows)
# Out:
# (5314, 1787, 930705, 96396, 12, 8033.0, 'B', 'Defaulter - Contract Finished')
# (5316, 1801, 930711, 165960, 36, 4610.0, 'A', 'Good - Contract Finished')
# (6863, 9188, 930728, 127080, 60, 2118.0, 'A', 'Good - Contract Finished')
# (5325, 1843, 930803, 105804, 36, 2939.0, 'A', 'Good - Contract Finished')
# (7240, 11013, 930906, 274740, 60, 4579.0, 'A', 'Good - Contract Finished')
# (6687, 8261, 930913, 87840, 24, 3660.0, 'A', 'Good - Contract Finished')
# (7284, 11265, 930915, 52788, 12, 4399.0, 'A', 'Good - Contract Finished')
# (6111, 5428, 930924, 174744, 24, 7281.0, 'B', 'Defaulter - Contract Finished')
# (7235, 10973, 931013, 154416, 48, 3217.0, 'A', 'Good - Contract Finished')
# (5997, 4894, 931104, 117024, 24, 4876.0, 'A', 'Good - Contract Finished')
# (7121, 10364, 931110, 21924, 36, 609.0, 'A', 'Good - Contract Finished')
# (6077, 5270, 931122, 79608, 24, 3317.0, 'A', 'Good - Contract Finished')
# (6228, 6034, 931201, 464520, 60, 7742.0, 'B', 'Defaulter - Contract Finished')
# (6356, 6701, 931208, 95400, 36, 2650.0, 'A', 'Good - Contract Finished')
# (5523, 2705, 931208, 93888, 36, 2608.0, 'A', 'Good - Contract Finished')
# (6456, 7123, 931209, 47016, 12, 3918.0, 'A', 'Good - Contract Finished')
# (7104, 10320, 931213, 259740, 60, 4329.0, 'A', 'Good - Contract Finished')
# (6820, 9034, 931216, 38148, 12, 3179.0, 'A', 'Good - Contract Finished')
# (6876, 9236, 931221, 86616, 12, 7218.0, 'A', 'Good - Contract Finished')
# (7097, 10266, 931223, 75624, 24, 3151.0, 'B', 'Defaulter - Contract Finished')
# (4959, 2, 940105, 80952, 24, 3373.0, 'A', 'Good - Contract Finished')
# (6499, 7401, 940105, 80952, 24, 3373.0, 'A', 'Good - Contract Finished')
# (5479, 2486, 940110, 24516, 12, 2043.0, 'A', 'Good - Contract Finished')
# (5170, 1071, 940120, 253200, 60, 4220.0, 'C', 'Good - Contract Running')
# (6721, 8475, 940121, 21072, 24, 878.0, 'A', 'Good - Contract Finished')
# (7259, 11111, 940131, 108144, 36, 3004.0, 'A', 'Good - Contract Finished')
# (5285, 1603, 940206, 78936, 12, 6578.0, 'A', 'Good - Contract Finished')
# (5189, 1166, 940207, 149040, 48, 3105.0, 'A', 'Good - Contract Finished')
# (6650, 8073, 940217, 49320, 12, 4110.0, 'B', 'Defaulter - Contract Finished')
# (7226, 10940, 940223, 197748, 36, 5493.0, 'A', 'Good - Contract Finished')
# (6087, 5313, 940227, 300660, 60, 5011.0, 'C', 'Good - Contract Running')
# (7262, 11135, 940301, 182628, 36, 5073.0, 'A', 'Good - Contract Finished')
# (5519, 2694, 940308, 91632, 12, 7636.0, 'A', 'Good - Contract Finished')
# (6577, 7753, 940311, 51696, 24, 2154.0, 'A', 'Good - Contract Finished')
# (6509, 7445, 940315, 55368, 24, 2307.0, 'A', 'Good - Contract Finished')
# (6520, 7485, 940316, 91200, 24, 3800.0, 'A', 'Good - Contract Finished')
# (6699, 8330, 940330, 7656, 24, 319.0, 'A', 'Good - Contract Finished')
# (6336, 6555, 940331, 212400, 36, 5900.0, 'A', 'Good - Contract Finished')
# (7055, 10079, 940406, 167100, 60, 2785.0, 'C', 'Good - Contract Running')
# (6103, 5385, 940407, 149340, 60, 2489.0, 'C', 'Good - Contract Running')
# (6202, 5891, 940418, 65184, 12, 5432.0, 'A', 'Good - Contract Finished')
# (7066, 10131, 940502, 215388, 36, 5983.0, 'B', 'Defaulter - Contract Finished')
# (6696, 8321, 940509, 89040, 60, 1484.0, 'C', 'Good - Contract Running')
# (6072, 5256, 940510, 193968, 36, 5388.0, 'A', 'Good - Contract Finished')
# (5130, 813, 940511, 24312, 12, 2026.0, 'A', 'Good - Contract Finished')
# (5568, 2933, 940517, 272520, 60, 4542.0, 'C', 'Good - Contract Running')
# (6678, 8173, 940520, 80340, 12, 6695.0, 'A', 'Good - Contract Finished')
# (6998, 9833, 940521, 97632, 12, 8136.0, 'A', 'Good - Contract Finished')
# (6580, 7769, 940522, 196080, 48, 4085.0, 'A', 'Good - Contract Finished')
# (6316, 6473, 940526, 76908, 12, 6409.0, 'B', 'Defaulter - Contract Finished')
# (6512, 7454, 940526, 63312, 48, 1319.0, 'A', 'Good - Contract Finished')
# (6407, 6930, 940526, 25944, 24, 1081.0, 'A', 'Good - Contract Finished')
# (5002, 173, 940531, 104808, 12, 8734.0, 'A', 'Good - Contract Finished')
# (6647, 8051, 940601, 208320, 48, 4340.0, 'A', 'Good - Contract Finished')
# (7137, 10439, 940603, 151560, 24, 6315.0, 'A', 'Good - Contract Finished')
# (6903, 9337, 940604, 52128, 24, 2172.0, 'A', 'Good - Contract Finished')
# (5918, 4576, 940604, 300204, 36, 8339.0, 'A', 'Good - Contract Finished')
# (6642, 8027, 940605, 77640, 12, 6470.0, 'A', 'Good - Contract Finished')
# (6210, 5927, 940606, 87216, 48, 1817.0, 'B', 'Defaulter - Contract Finished')
# (6279, 6273, 940607, 87360, 24, 3640.0, 'A', 'Good - Contract Finished')
# (7249, 11065, 940612, 69360, 48, 1445.0, 'A', 'Good - Contract Finished')
# (6736, 8558, 940614, 288360, 60, 4806.0, 'C', 'Good - Contract Running')
# (6112, 5442, 940617, 174744, 24, 7281.0, 'B', 'Defaulter - Contract Finished')
# (5319, 1811, 940623, 239460, 60, 3991.0, 'C', 'Good - Contract Running')
# (6596, 7844, 940625, 91584, 24, 3816.0, 'A', 'Good - Contract Finished')
# (5837, 4260, 940629, 244560, 60, 4076.0, 'C', 'Good - Contract Running')
# (5657, 3354, 940705, 4980, 12, 415.0, 'A', 'Good - Contract Finished')
# (5533, 2762, 940705, 111384, 24, 4641.0, 'A', 'Good - Contract Finished')
# (6232, 6051, 940708, 276660, 36, 7685.0, 'B', 'Defaulter - Contract Finished')
# (6888, 9265, 940711, 39576, 12, 3298.0, 'A', 'Good - Contract Finished')
# (6066, 5228, 940711, 173808, 24, 7242.0, 'A', 'Good - Contract Finished')
# (5549, 2824, 940716, 50460, 60, 841.0, 'C', 'Good - Contract Running')
# (5060, 426, 940719, 252060, 60, 4201.0, 'D', 'In Debt - Contract Running')
# (6004, 4937, 940723, 143904, 24, 5996.0, 'A', 'Good - Contract Finished')
# (5126, 790, 940724, 208128, 48, 4336.0, 'B', 'Defaulter - Contract Finished')
# (7220, 10911, 940728, 131292, 36, 3647.0, 'A', 'Good - Contract Finished')
# (6668, 8129, 940730, 74736, 36, 2076.0, 'A', 'Good - Contract Finished')
# (5395, 2176, 940730, 299088, 36, 8308.0, 'B', 'Defaulter - Contract Finished')
# (6836, 9093, 940803, 189300, 60, 3155.0, 'C', 'Good - Contract Running')
# (6064, 5215, 940804, 14628, 12, 1219.0, 'A', 'Good - Contract Finished')
# (6919, 9403, 940805, 120888, 36, 3358.0, 'A', 'Good - Contract Finished')
# (6841, 9104, 940807, 172080, 48, 3585.0, 'A', 'Good - Contract Finished')
# (6038, 5120, 940810, 323472, 48, 6739.0, 'A', 'Good - Contract Finished')
# (6729, 8519, 940811, 74688, 12, 6224.0, 'A', 'Good - Contract Finished')
# (7198, 10788, 940823, 45768, 12, 3814.0, 'A', 'Good - Contract Finished')
# (6686, 8260, 940825, 224604, 36, 6239.0, 'A', 'Good - Contract Finished')
# (5836, 4259, 940827, 79632, 24, 3318.0, 'A', 'Good - Contract Finished')
# (7061, 10105, 940827, 121896, 24, 5079.0, 'A', 'Good - Contract Finished')
# (5595, 3050, 940902, 82896, 12, 6908.0, 'A', 'Good - Contract Finished')
# (5723, 3674, 940910, 23628, 12, 1969.0, 'A', 'Good - Contract Finished')
# (6120, 5481, 940911, 209184, 48, 4358.0, 'A', 'Good - Contract Finished')
# (6895, 9307, 940919, 41904, 12, 3492.0, 'A', 'Good - Contract Finished')
# (5882, 4427, 940926, 87816, 12, 7318.0, 'A', 'Good - Contract Finished')
# (5754, 3834, 940928, 23052, 12, 1921.0, 'A', 'Good - Contract Finished')
# (6594, 7824, 940928, 189696, 24, 7904.0, 'B', 'Defaulter - Contract Finished')
# (6738, 8566, 940929, 230220, 36, 6395.0, 'B', 'Defaulter - Contract Finished')
# (6624, 7965, 940930, 71460, 12, 5955.0, 'A', 'Good - Contract Finished')
# (6216, 5952, 940930, 141240, 24, 5885.0, 'A', 'Good - Contract Finished')
# (6229, 6040, 941002, 11736, 24, 489.0, 'A', 'Good - Contract Finished')
# (5887, 4448, 941003, 192744, 36, 5354.0, 'A', 'Good - Contract Finished')
# (6808, 8982, 941012, 227880, 36, 6330.0, 'A', 'Good - Contract Finished')
# (6297, 6363, 941025, 17508, 12, 1459.0, 'A', 'Good - Contract Finished')
# (5161, 1012, 941028, 98184, 24, 4091.0, 'A', 'Good - Contract Finished')
# (5390, 2167, 941030, 170256, 24, 7094.0, 'A', 'Good - Contract Finished')
# (6150, 5622, 941102, 83016, 12, 6918.0, 'A', 'Good - Contract Finished')
# (6223, 5991, 941103, 61056, 48, 1272.0, 'A', 'Good - Contract Finished')
# (5032, 290, 941103, 123696, 48, 2577.0, 'A', 'Good - Contract Finished')
# (6253, 6148, 941104, 59760, 24, 2490.0, 'A', 'Good - Contract Finished')
# (6460, 7133, 941106, 48672, 36, 1352.0, 'A', 'Good - Contract Finished')
# (6645, 8041, 941106, 140400, 36, 3900.0, 'A', 'Good - Contract Finished')
# (5176, 1106, 941112, 192552, 24, 8023.0, 'B', 'Defaulter - Contract Finished')
# (5269, 1527, 941119, 164052, 36, 4557.0, 'B', 'Defaulter - Contract Finished')
# (5351, 1978, 941204, 205200, 36, 5700.0, 'A', 'Good - Contract Finished')
# (5861, 4337, 941208, 51408, 24, 2142.0, 'A', 'Good - Contract Finished')
# (5450, 2345, 941211, 199680, 60, 3328.0, 'C', 'Good - Contract Running')
# (7142, 10451, 941219, 482940, 60, 8049.0, 'D', 'In Debt - Contract Running')
# (6306, 6425, 941220, 36684, 12, 3057.0, 'A', 'Good - Contract Finished')
# (6272, 6226, 941220, 398640, 60, 6644.0, 'C', 'Good - Contract Running')
# (5044, 344, 941221, 100980, 60, 1683.0, 'C', 'Good - Contract Running')
# (5576, 2962, 941221, 31248, 12, 2604.0, 'A', 'Good - Contract Finished')
# (7192, 10738, 941221, 115992, 36, 3222.0, 'A', 'Good - Contract Finished')
# (5739, 3747, 950102, 76380, 12, 6365.0, 'A', 'Good - Contract Finished')
# (6526, 7523, 950103, 288468, 36, 8013.0, 'A', 'Good - Contract Finished')
# (5624, 3166, 950103, 177744, 48, 3703.0, 'D', 'In Debt - Contract Running')
# (6244, 6118, 950108, 270648, 36, 7518.0, 'B', 'Defaulter - Contract Finished')
# (5131, 816, 950108, 48624, 24, 2026.0, 'A', 'Good - Contract Finished')
# (6960, 9640, 950111, 76416, 24, 3184.0, 'A', 'Good - Contract Finished')
# (6358, 6715, 950114, 137880, 60, 2298.0, 'D', 'In Debt - Contract Running')
# (5418, 2245, 950116, 347952, 48, 7249.0, 'C', 'Good - Contract Running')
# (6598, 7857, 950118, 68112, 12, 5676.0, 'A', 'Good - Contract Finished')
# (5464, 2419, 950130, 95808, 12, 7984.0, 'A', 'Good - Contract Finished')
# (6591, 7819, 950202, 20832, 48, 434.0, 'C', 'Good - Contract Running')
# (5724, 3678, 950205, 316140, 60, 5269.0, 'D', 'In Debt - Contract Running')
# (6315, 6472, 950206, 43164, 12, 3597.0, 'A', 'Good - Contract Finished')
# (5876, 4413, 950208, 221280, 48, 4610.0, 'C', 'Good - Contract Running')
# (6986, 9750, 950211, 151728, 48, 3161.0, 'D', 'In Debt - Contract Running')
# (6294, 6353, 950212, 79920, 60, 1332.0, 'C', 'Good - Contract Running')
# (5132, 817, 950217, 538500, 60, 8975.0, 'C', 'Good - Contract Running')
# (5877, 4414, 950223, 97224, 24, 4051.0, 'A', 'Good - Contract Finished')
# (6227, 6030, 950304, 28248, 24, 1177.0, 'A', 'Good - Contract Finished')
# (7241, 11021, 950304, 168984, 24, 7041.0, 'B', 'Defaulter - Contract Finished')
# (6737, 8564, 950311, 76680, 24, 3195.0, 'A', 'Good - Contract Finished')
# (7004, 9869, 950315, 331560, 60, 5526.0, 'C', 'Good - Contract Running')
# (6169, 5700, 950316, 103680, 60, 1728.0, 'D', 'In Debt - Contract Running')
# (5208, 1247, 950316, 99696, 48, 2077.0, 'D', 'In Debt - Contract Running')
# (6694, 8316, 950319, 134784, 24, 5616.0, 'A', 'Good - Contract Finished')
# (5599, 3064, 950321, 15420, 12, 1285.0, 'A', 'Good - Contract Finished')
# (6546, 7607, 950327, 31728, 24, 1322.0, 'A', 'Good - Contract Finished')
# (5414, 2228, 950329, 185952, 48, 3874.0, 'C', 'Good - Contract Running')
# (5453, 2361, 950401, 156672, 36, 4352.0, 'A', 'Good - Contract Finished')
# (5740, 3752, 950402, 18564, 12, 1547.0, 'A', 'Good - Contract Finished')
# (5804, 4079, 950405, 158976, 48, 3312.0, 'C', 'Good - Contract Running')
# (6745, 8625, 950410, 47304, 24, 1971.0, 'A', 'Good - Contract Finished')
# (6950, 9591, 950411, 104712, 24, 4363.0, 'A', 'Good - Contract Finished')
# (6996, 9828, 950413, 126600, 24, 5275.0, 'A', 'Good - Contract Finished')
# (5352, 1993, 950415, 68400, 12, 5700.0, 'B', 'Defaulter - Contract Finished')
# (6151, 5628, 950425, 225420, 60, 3757.0, 'C', 'Good - Contract Running')
# (5310, 1762, 950428, 248148, 36, 6893.0, 'A', 'Good - Contract Finished')
# (5045, 347, 950501, 187224, 24, 7801.0, 'B', 'Defaulter - Contract Finished')
# (6929, 9472, 950508, 36396, 12, 3033.0, 'A', 'Good - Contract Finished')
# (5151, 960, 950524, 189060, 60, 3151.0, 'C', 'Good - Contract Running')
# (5212, 1256, 950529, 71064, 36, 1974.0, 'A', 'Good - Contract Finished')
# (5138, 854, 950530, 87216, 48, 1817.0, 'C', 'Good - Contract Running')
# (5713, 3629, 950530, 158760, 60, 2646.0, 'C', 'Good - Contract Running')
# (6704, 8377, 950601, 417060, 60, 6951.0, 'C', 'Good - Contract Running')
# (6474, 7190, 950606, 63360, 60, 1056.0, 'C', 'Good - Contract Running')
# (6676, 8159, 950613, 29784, 24, 1241.0, 'A', 'Good - Contract Finished')
# (6965, 9656, 950613, 139536, 24, 5814.0, 'A', 'Good - Contract Finished')
# (6725, 8489, 950623, 265320, 36, 7370.0, 'A', 'Good - Contract Finished')
# (7166, 10630, 950624, 198240, 24, 8260.0, 'A', 'Good - Contract Finished')
# (7138, 10440, 950703, 60000, 60, 1000.0, 'C', 'Good - Contract Running')
# (5970, 4774, 950709, 465072, 48, 9689.0, 'C', 'Good - Contract Running')
# (6157, 5650, 950710, 98592, 24, 4108.0, 'A', 'Good - Contract Finished')
# (6153, 5632, 950725, 285600, 60, 4760.0, 'C', 'Good - Contract Running')
# (5693, 3489, 950801, 44088, 24, 1837.0, 'A', 'Good - Contract Finished')
# (5922, 4580, 950805, 20220, 12, 1685.0, 'A', 'Good - Contract Finished')
# (5959, 4727, 950811, 107640, 24, 4485.0, 'A', 'Good - Contract Finished')
# (5980, 4825, 950818, 21396, 12, 1783.0, 'A', 'Good - Contract Finished')
# (6764, 8776, 950826, 33984, 48, 708.0, 'C', 'Good - Contract Running')
# (5237, 1375, 950829, 45336, 24, 1889.0, 'A', 'Good - Contract Finished')
# (6726, 8492, 950903, 85860, 60, 1431.0, 'C', 'Good - Contract Running')
# (6933, 9493, 950909, 188688, 48, 3931.0, 'C', 'Good - Contract Running')
# (5145, 915, 950916, 309552, 48, 6449.0, 'C', 'Good - Contract Running')
# (7008, 9897, 950922, 36168, 12, 3014.0, 'A', 'Good - Contract Finished')
# (7227, 10942, 951002, 314520, 60, 5242.0, 'C', 'Good - Contract Running')
# (6600, 7861, 951008, 21852, 36, 607.0, 'A', 'Good - Contract Finished')
# (6712, 8405, 951014, 266220, 60, 4437.0, 'C', 'Good - Contract Running')
# (7057, 10093, 951020, 231696, 36, 6436.0, 'A', 'Good - Contract Finished')
# (7176, 10663, 951028, 260028, 36, 7223.0, 'A', 'Good - Contract Finished')
# (7304, 11349, 951029, 419880, 60, 6998.0, 'C', 'Good - Contract Running')
# (6362, 6738, 951031, 37908, 12, 3159.0, 'A', 'Good - Contract Finished')
# (5880, 4423, 951031, 73836, 36, 2051.0, 'A', 'Good - Contract Finished')
# (6535, 7546, 951102, 41952, 12, 3496.0, 'A', 'Good - Contract Finished')
# (5449, 2343, 951104, 99336, 24, 4139.0, 'A', 'Good - Contract Finished')
# (6342, 6609, 951112, 60156, 36, 1671.0, 'B', 'Defaulter - Contract Finished')
# (5409, 2218, 951118, 182040, 60, 3034.0, 'C', 'Good - Contract Running')
# (6955, 9627, 951122, 244368, 48, 5091.0, 'C', 'Good - Contract Running')
# (6985, 9731, 951122, 113796, 36, 3161.0, 'A', 'Good - Contract Finished')
# (5125, 789, 951123, 73056, 48, 1522.0, 'C', 'Good - Contract Running')
# (5805, 4081, 951128, 137904, 24, 5746.0, 'B', 'Defaulter - Contract Finished')
# (6185, 5774, 951128, 31176, 24, 1299.0, 'A', 'Good - Contract Finished')
# (7243, 11042, 951204, 217152, 36, 6032.0, 'A', 'Good - Contract Finished')
# (6403, 6924, 951205, 194880, 48, 4060.0, 'C', 'Good - Contract Running')
# (6578, 7765, 951211, 27984, 12, 2332.0, 'A', 'Good - Contract Finished')
# (5413, 2227, 951212, 92976, 24, 3874.0, 'A', 'Good - Contract Finished')
# (6949, 9583, 951212, 104712, 24, 4363.0, 'A', 'Good - Contract Finished')
# (6545, 7606, 951212, 191880, 60, 3198.0, 'C', 'Good - Contract Running')
# (6178, 5742, 951216, 232560, 48, 4845.0, 'C', 'Good - Contract Running')
# (5160, 1011, 951218, 204000, 60, 3400.0, 'C', 'Good - Contract Running')
# (6785, 8899, 951225, 125340, 60, 2089.0, 'C', 'Good - Contract Running')
# (6540, 7562, 951231, 309600, 48, 6450.0, 'C', 'Good - Contract Running')
# (6589, 7815, 960101, 189696, 24, 7904.0, 'A', 'Good - Contract Finished')
# (5900, 4503, 960101, 135360, 48, 2820.0, 'C', 'Good - Contract Running')
# (5999, 4907, 960103, 98832, 48, 2059.0, 'C', 'Good - Contract Running')
# (6043, 5126, 960111, 20352, 48, 424.0, 'C', 'Good - Contract Running')
# (5482, 2496, 960112, 165120, 60, 2752.0, 'C', 'Good - Contract Running')
# (7263, 11138, 960119, 89880, 24, 3745.0, 'A', 'Good - Contract Finished')
# (6013, 4995, 960203, 128988, 36, 3583.0, 'D', 'In Debt - Contract Running')
# (5750, 3804, 960208, 63252, 12, 5271.0, 'A', 'Good - Contract Finished')
# (6027, 5066, 960210, 61656, 24, 2569.0, 'B', 'Defaulter - Contract Finished')
# (6303, 6400, 960212, 72408, 24, 3017.0, 'B', 'Defaulter - Contract Finished')
# (7213, 10884, 960213, 113544, 36, 3154.0, 'C', 'Good - Contract Running')
# (6659, 8092, 960220, 56100, 60, 935.0, 'C', 'Good - Contract Running')
# (6175, 5735, 960221, 290700, 60, 4845.0, 'D', 'In Debt - Contract Running')
# (5610, 3112, 960224, 123216, 48, 2567.0, 'C', 'Good - Contract Running')
# (5563, 2912, 960229, 380160, 60, 6336.0, 'C', 'Good - Contract Running')
# (5989, 4852, 960304, 213300, 36, 5925.0, 'C', 'Good - Contract Running')
# (6698, 8327, 960310, 247728, 48, 5161.0, 'C', 'Good - Contract Running')
# (5312, 1772, 960313, 202788, 36, 5633.0, 'C', 'Good - Contract Running')
# (7189, 10728, 960321, 154656, 48, 3222.0, 'C', 'Good - Contract Running')
# (6816, 9017, 960326, 100224, 48, 2088.0, 'D', 'In Debt - Contract Running')
# (6137, 5574, 960410, 44628, 12, 3719.0, 'A', 'Good - Contract Finished')
# (5128, 808, 960411, 215616, 48, 4492.0, 'D', 'In Debt - Contract Running')
# (5470, 2456, 960415, 200976, 48, 4187.0, 'C', 'Good - Contract Running')
# (5593, 3037, 960418, 277884, 36, 7719.0, 'D', 'In Debt - Contract Running')
# (5350, 1967, 960421, 249312, 48, 5194.0, 'C', 'Good - Contract Running')
# (6063, 5213, 960425, 320976, 48, 6687.0, 'D', 'In Debt - Contract Running')
# (6501, 7418, 960429, 30276, 12, 2523.0, 'B', 'Defaulter - Contract Finished')
# (5452, 2352, 960429, 49440, 60, 824.0, 'C', 'Good - Contract Running')
# (4961, 19, 960429, 30276, 12, 2523.0, 'B', 'Defaulter - Contract Finished')
# (4973, 67, 960502, 165960, 24, 6915.0, 'A', 'Good - Contract Finished')
# (6190, 5794, 960506, 123600, 60, 2060.0, 'C', 'Good - Contract Running')
# (6715, 8411, 960506, 220620, 60, 3677.0, 'C', 'Good - Contract Running')
# (5892, 4462, 960514, 66480, 24, 2770.0, 'B', 'Defaulter - Contract Finished')
# (6550, 7614, 960518, 320592, 48, 6679.0, 'C', 'Good - Contract Running')
# (5706, 3608, 960524, 161496, 36, 4486.0, 'C', 'Good - Contract Running')
# (5148, 940, 960529, 284280, 60, 4738.0, 'C', 'Good - Contract Running')
# (6734, 8547, 960530, 173016, 36, 4806.0, 'C', 'Good - Contract Running')
# (6109, 5422, 960603, 368880, 60, 6148.0, 'C', 'Good - Contract Running')
# (6961, 9645, 960606, 176148, 36, 4893.0, 'C', 'Good - Contract Running')
# (6810, 9006, 960608, 186384, 48, 3883.0, 'C', 'Good - Contract Running')
# (5494, 2572, 960613, 360000, 48, 7500.0, 'C', 'Good - Contract Running')
# (5311, 1766, 960615, 30060, 60, 501.0, 'C', 'Good - Contract Running')
# (5445, 2322, 960629, 46320, 24, 1930.0, 'A', 'Good - Contract Finished')
# (5301, 1698, 960706, 141948, 36, 3943.0, 'C', 'Good - Contract Running')
# (7034, 10001, 960711, 19044, 36, 529.0, 'C', 'Good - Contract Running')
# (6751, 8680, 960714, 85716, 36, 2381.0, 'C', 'Good - Contract Running')
# (6667, 8127, 960715, 155880, 24, 6495.0, 'A', 'Good - Contract Finished')
# (6130, 5541, 960718, 32640, 48, 680.0, 'C', 'Good - Contract Running')
# (5429, 2268, 960718, 20196, 36, 561.0, 'C', 'Good - Contract Running')
# (5725, 3679, 960723, 444864, 48, 9268.0, 'C', 'Good - Contract Running')
# (6019, 5033, 960725, 11400, 12, 950.0, 'A', 'Good - Contract Finished')
# (6421, 6985, 960725, 96768, 36, 2688.0, 'C', 'Good - Contract Running')
# (6992, 9790, 960727, 133968, 48, 2791.0, 'C', 'Good - Contract Running')
# (5136, 846, 960728, 187104, 24, 7796.0, 'A', 'Good - Contract Finished')
# (5337, 1886, 960731, 162468, 36, 4513.0, 'C', 'Good - Contract Running')
# (5495, 2580, 960802, 89340, 60, 1489.0, 'C', 'Good - Contract Running')
# (7013, 9928, 960802, 89340, 60, 1489.0, 'C', 'Good - Contract Running')
# (6012, 4994, 960803, 258444, 36, 7179.0, 'C', 'Good - Contract Running')
# (6471, 7184, 960804, 155640, 24, 6485.0, 'A', 'Good - Contract Finished')
# (6296, 6358, 960806, 270384, 48, 5633.0, 'C', 'Good - Contract Running')
# (7305, 11359, 960806, 54024, 12, 4502.0, 'A', 'Good - Contract Finished')
# (6144, 5593, 960809, 44376, 12, 3698.0, 'A', 'Good - Contract Finished')
# (6283, 6289, 960811, 85632, 48, 1784.0, 'C', 'Good - Contract Running')
# (7246, 11054, 960820, 148920, 60, 2482.0, 'C', 'Good - Contract Running')
# (5088, 544, 960822, 91152, 24, 3798.0, 'A', 'Good - Contract Finished')
# (5988, 4851, 960822, 141648, 24, 5902.0, 'A', 'Good - Contract Finished')
# (5282, 1583, 960824, 388512, 48, 8094.0, 'D', 'In Debt - Contract Running')
# (5938, 4650, 960825, 402000, 60, 6700.0, 'C', 'Good - Contract Running')
# (5606, 3084, 960828, 253512, 36, 7042.0, 'D', 'In Debt - Contract Running')
# (5385, 2143, 960909, 71460, 36, 1985.0, 'C', 'Good - Contract Running')
# (6865, 9199, 960911, 29448, 12, 2454.0, 'B', 'Defaulter - Contract Finished')
# (5586, 2994, 960914, 48744, 36, 1354.0, 'C', 'Good - Contract Running')
# (6302, 6397, 960916, 181020, 60, 3017.0, 'C', 'Good - Contract Running')
# (7194, 10762, 960917, 68832, 36, 1912.0, 'C', 'Good - Contract Running')
# (6461, 7136, 960919, 74124, 36, 2059.0, 'C', 'Good - Contract Running')
# (6732, 8533, 960919, 174048, 48, 3626.0, 'C', 'Good - Contract Running')
# (6613, 7926, 960922, 84120, 24, 3505.0, 'A', 'Good - Contract Finished')
# (7036, 10019, 960925, 194940, 36, 5415.0, 'C', 'Good - Contract Running')
# (5897, 4476, 960925, 15192, 24, 633.0, 'A', 'Good - Contract Finished')
# (6995, 9814, 960926, 96168, 12, 8014.0, 'A', 'Good - Contract Finished')
# (5415, 2236, 960926, 139464, 36, 3874.0, 'D', 'In Debt - Contract Running')
# (7136, 10436, 960928, 54396, 36, 1511.0, 'C', 'Good - Contract Running')
# (7271, 11186, 961002, 392460, 60, 6541.0, 'C', 'Good - Contract Running')
# (5375, 2106, 961003, 101520, 12, 8460.0, 'A', 'Good - Contract Finished')
# (5635, 3230, 961004, 77184, 36, 2144.0, 'C', 'Good - Contract Running')
# (6817, 9024, 961004, 70656, 48, 1472.0, 'C', 'Good - Contract Running')
# (5923, 4585, 961010, 64656, 48, 1347.0, 'C', 'Good - Contract Running')
# (5329, 1862, 961016, 396120, 60, 6602.0, 'C', 'Good - Contract Running')
# (6644, 8039, 961020, 93600, 24, 3900.0, 'A', 'Good - Contract Finished')
# (6354, 6688, 961023, 22968, 36, 638.0, 'C', 'Good - Contract Running')
# (5082, 501, 961024, 262980, 60, 4383.0, 'C', 'Good - Contract Running')
# (6585, 7795, 961029, 372120, 60, 6202.0, 'C', 'Good - Contract Running')
# (6921, 9422, 961029, 86184, 12, 7182.0, 'A', 'Good - Contract Finished')
# (5366, 2062, 961029, 86184, 12, 7182.0, 'A', 'Good - Contract Finished')
# (5886, 4447, 961031, 192744, 36, 5354.0, 'C', 'Good - Contract Running')
# (5741, 3754, 961103, 68544, 24, 2856.0, 'A', 'Good - Contract Finished')
# (4996, 132, 961106, 88440, 12, 7370.0, 'A', 'Good - Contract Finished')
# (6015, 5001, 961109, 110112, 24, 4588.0, 'A', 'Good - Contract Finished')
# (6309, 6434, 961111, 110136, 24, 4589.0, 'A', 'Good - Contract Finished')
# (6073, 5263, 961112, 276300, 60, 4605.0, 'C', 'Good - Contract Running')
# (6006, 4948, 961115, 359760, 60, 5996.0, 'C', 'Good - Contract Running')
# (5611, 3115, 961115, 321180, 60, 5353.0, 'C', 'Good - Contract Running')
# (6944, 9548, 961115, 46176, 48, 962.0, 'C', 'Good - Contract Running')
# (7101, 10297, 961118, 421008, 48, 8771.0, 'C', 'Good - Contract Running')
# (6599, 7859, 961119, 72120, 12, 6010.0, 'A', 'Good - Contract Finished')
# (6940, 9510, 961122, 228276, 36, 6341.0, 'C', 'Good - Contract Running')
# (5209, 1250, 961125, 182640, 48, 3805.0, 'C', 'Good - Contract Running')
# (5388, 2153, 961128, 61560, 12, 5130.0, 'A', 'Good - Contract Finished')
# (6011, 4981, 961128, 179328, 48, 3736.0, 'C', 'Good - Contract Running')
# (5591, 3021, 961204, 155616, 48, 3242.0, 'C', 'Good - Contract Running')
# (7154, 10520, 961205, 417600, 60, 6960.0, 'C', 'Good - Contract Running')
# (7130, 10411, 961211, 123408, 24, 5142.0, 'A', 'Good - Contract Finished')
# (6818, 9030, 961212, 155616, 48, 3242.0, 'C', 'Good - Contract Running')
# (5625, 3189, 961215, 222180, 60, 3703.0, 'D', 'In Debt - Contract Running')
# (6805, 8972, 961221, 45024, 48, 938.0, 'C', 'Good - Contract Running')
# (7233, 10963, 961225, 115812, 36, 3217.0, 'C', 'Good - Contract Running')
# (7308, 11362, 961227, 129408, 24, 5392.0, 'A', 'Good - Contract Finished')
# (5895, 4473, 970103, 93960, 60, 1566.0, 'C', 'Good - Contract Running')
# (7122, 10365, 970104, 260640, 36, 7240.0, 'D', 'In Debt - Contract Running')
# (6173, 5724, 970108, 232560, 48, 4845.0, 'C', 'Good - Contract Running')
# (6142, 5591, 970121, 221880, 60, 3698.0, 'C', 'Good - Contract Running')
# (5358, 2018, 970121, 38520, 12, 3210.0, 'A', 'Good - Contract Finished')
# (6095, 5358, 970124, 68340, 60, 1139.0, 'C', 'Good - Contract Running')
# (6878, 9242, 970124, 23184, 12, 1932.0, 'A', 'Good - Contract Finished')
# (6554, 7637, 970129, 390096, 48, 8127.0, 'C', 'Good - Contract Running')
# (6793, 8931, 970130, 186300, 60, 3105.0, 'C', 'Good - Contract Running')
# (7286, 11271, 970131, 67320, 36, 1870.0, 'C', 'Good - Contract Running')
# (6076, 5269, 970202, 117420, 60, 1957.0, 'C', 'Good - Contract Running')
# (5134, 825, 970202, 53076, 12, 4423.0, 'A', 'Good - Contract Finished')
# (5419, 2246, 970205, 415800, 60, 6930.0, 'C', 'Good - Contract Running')
# (6255, 6158, 970208, 247920, 48, 5165.0, 'D', 'In Debt - Contract Running')
# (5656, 3353, 970209, 146064, 24, 6086.0, 'C', 'Good - Contract Running')
# (6934, 9494, 970209, 116832, 12, 9736.0, 'A', 'Good - Contract Finished')
# (6028, 5072, 970209, 317520, 60, 5292.0, 'C', 'Good - Contract Running')
# (6490, 7262, 970210, 73260, 60, 1221.0, 'C', 'Good - Contract Running')
# (6415, 6950, 970212, 475680, 48, 9910.0, 'C', 'Good - Contract Running')
# (7087, 10215, 970220, 44304, 24, 1846.0, 'C', 'Good - Contract Running')
# (5420, 2247, 970224, 72504, 24, 3021.0, 'C', 'Good - Contract Running')
# (5977, 4803, 970225, 59136, 48, 1232.0, 'C', 'Good - Contract Running')
# (6824, 9052, 970226, 71976, 24, 2999.0, 'D', 'In Debt - Contract Running')
# (5207, 1244, 970228, 35904, 48, 748.0, 'C', 'Good - Contract Running')
# (7115, 10351, 970304, 88704, 48, 1848.0, 'C', 'Good - Contract Running')
# (7250, 11069, 970304, 119136, 48, 2482.0, 'C', 'Good - Contract Running')
# (6010, 4969, 970306, 150180, 60, 2503.0, 'C', 'Good - Contract Running')
# (6088, 5317, 970307, 90180, 36, 2505.0, 'C', 'Good - Contract Running')
# (5682, 3455, 970307, 67464, 12, 5622.0, 'A', 'Good - Contract Finished')
# (7201, 10807, 970307, 67464, 12, 5622.0, 'A', 'Good - Contract Finished')
# (6938, 9504, 970310, 341280, 60, 5688.0, 'C', 'Good - Contract Running')
# (6875, 9235, 970313, 83280, 48, 1735.0, 'C', 'Good - Contract Running')
# (5953, 4715, 970314, 97176, 24, 4049.0, 'C', 'Good - Contract Running')
# (5942, 4681, 970315, 162624, 48, 3388.0, 'C', 'Good - Contract Running')
# (5382, 2134, 970317, 22932, 36, 637.0, 'C', 'Good - Contract Running')
# (6377, 6792, 970317, 17184, 12, 1432.0, 'A', 'Good - Contract Finished')
# (5931, 4618, 970317, 66696, 24, 2779.0, 'D', 'In Debt - Contract Running')
# (5992, 4863, 970318, 76080, 12, 6340.0, 'A', 'Good - Contract Finished')
# (5790, 4033, 970320, 84288, 48, 1756.0, 'C', 'Good - Contract Running')
# (6753, 8688, 970320, 67980, 12, 5665.0, 'A', 'Good - Contract Finished')
# (6562, 7674, 970321, 94488, 24, 3937.0, 'C', 'Good - Contract Running')
# (7046, 10049, 970328, 91632, 12, 7636.0, 'A', 'Good - Contract Finished')
# (5868, 4361, 970329, 90156, 12, 7513.0, 'A', 'Good - Contract Finished')
# (5784, 3967, 970329, 84600, 36, 2350.0, 'D', 'In Debt - Contract Running')
# (5878, 4415, 970401, 74040, 12, 6170.0, 'A', 'Good - Contract Finished')
# (5110, 675, 970401, 102240, 60, 1704.0, 'C', 'Good - Contract Running')
# (5210, 1252, 970401, 148140, 36, 4115.0, 'C', 'Good - Contract Running')
# (7230, 10954, 970402, 18720, 60, 312.0, 'C', 'Good - Contract Running')
# (5005, 176, 970410, 27456, 12, 2288.0, 'A', 'Good - Contract Finished')
# (6871, 9225, 970413, 164256, 48, 3422.0, 'C', 'Good - Contract Running')
# (5363, 2051, 970422, 293880, 60, 4898.0, 'D', 'In Debt - Contract Running')
# (7253, 11079, 970426, 98304, 12, 8192.0, 'A', 'Good - Contract Finished')
# (6055, 5181, 970428, 399120, 60, 6652.0, 'C', 'Good - Contract Running')
# (5072, 472, 970428, 196800, 24, 8200.0, 'D', 'In Debt - Contract Running')
# (6913, 9377, 970429, 99936, 24, 4164.0, 'C', 'Good - Contract Running')
# (6386, 6856, 970430, 124344, 36, 3454.0, 'C', 'Good - Contract Running')
# (5634, 3229, 970501, 39024, 12, 3252.0, 'A', 'Good - Contract Finished')
# (5758, 3859, 970502, 307200, 60, 5120.0, 'D', 'In Debt - Contract Running')
# (6819, 9031, 970503, 50112, 24, 2088.0, 'C', 'Good - Contract Running')
# (7088, 10233, 970503, 239160, 60, 3986.0, 'C', 'Good - Contract Running')
# (5039, 314, 970503, 66840, 24, 2785.0, 'C', 'Good - Contract Running')
# (5532, 2754, 970504, 335280, 48, 6985.0, 'C', 'Good - Contract Running')
# (6037, 5118, 970504, 53232, 48, 1109.0, 'C', 'Good - Contract Running')
# (6322, 6510, 970506, 76992, 24, 3208.0, 'C', 'Good - Contract Running')
# (6887, 9263, 970508, 39576, 12, 3298.0, 'A', 'Good - Contract Finished')
# (6660, 8094, 970509, 220428, 36, 6123.0, 'C', 'Good - Contract Running')
# (5451, 2350, 970511, 159744, 48, 3328.0, 'C', 'Good - Contract Running')
# (6014, 4999, 970518, 165168, 36, 4588.0, 'C', 'Good - Contract Running')
# (5556, 2872, 970519, 268320, 60, 4472.0, 'C', 'Good - Contract Running')
# (6346, 6649, 970522, 100260, 60, 1671.0, 'C', 'Good - Contract Running')
# (5850, 4293, 970522, 164196, 36, 4561.0, 'C', 'Good - Contract Running')
# (5940, 4660, 970528, 106944, 24, 4456.0, 'C', 'Good - Contract Running')
# (7119, 10361, 970602, 86880, 12, 7240.0, 'A', 'Good - Contract Finished')
# (5253, 1447, 970603, 100080, 48, 2085.0, 'C', 'Good - Contract Running')
# (6851, 9138, 970603, 272220, 60, 4537.0, 'D', 'In Debt - Contract Running')
# (6695, 8320, 970604, 309660, 60, 5161.0, 'C', 'Good - Contract Running')
# (6908, 9353, 970608, 188616, 24, 7859.0, 'C', 'Good - Contract Running')
# (7255, 11096, 970609, 213300, 60, 3555.0, 'C', 'Good - Contract Running')
# (5674, 3418, 970610, 207264, 48, 4318.0, 'C', 'Good - Contract Running')
# (6278, 6265, 970610, 87360, 24, 3640.0, 'C', 'Good - Contract Running')
# (5486, 2516, 970613, 466608, 48, 9721.0, 'C', 'Good - Contract Running')
# (5174, 1093, 970613, 385104, 48, 8023.0, 'C', 'Good - Contract Running')
# (6621, 7957, 970614, 42900, 12, 3575.0, 'A', 'Good - Contract Finished')
# (6313, 6461, 970615, 150912, 36, 4192.0, 'C', 'Good - Contract Running')
# (6435, 7045, 970616, 288720, 48, 6015.0, 'C', 'Good - Contract Running')
# (6970, 9677, 970617, 31620, 60, 527.0, 'C', 'Good - Contract Running')
# (6310, 6440, 970617, 34572, 12, 2881.0, 'A', 'Good - Contract Finished')
# (5932, 4626, 970618, 33348, 12, 2779.0, 'A', 'Good - Contract Finished')
# (6877, 9241, 970619, 285240, 60, 4754.0, 'C', 'Good - Contract Running')
# (6763, 8772, 970619, 88272, 48, 1839.0, 'C', 'Good - Contract Running')
# (7085, 10202, 970619, 305424, 48, 6363.0, 'C', 'Good - Contract Running')
# (7049, 10063, 970624, 233424, 36, 6484.0, 'C', 'Good - Contract Running')
# (6959, 9633, 970630, 59448, 24, 2477.0, 'D', 'In Debt - Contract Running')
# (5214, 1270, 970701, 74772, 36, 2077.0, 'C', 'Good - Contract Running')
# (6350, 6678, 970709, 294384, 48, 6133.0, 'C', 'Good - Contract Running')
# (5063, 442, 970710, 357840, 48, 7455.0, 'D', 'In Debt - Contract Running')
# (5041, 319, 970711, 369000, 60, 6150.0, 'C', 'Good - Contract Running')
# (5086, 525, 970716, 210384, 48, 4383.0, 'C', 'Good - Contract Running')
# (6942, 9513, 970716, 18324, 12, 1527.0, 'A', 'Good - Contract Finished')
# (5270, 1528, 970721, 191088, 48, 3981.0, 'C', 'Good - Contract Running')
# (6705, 8381, 970725, 333648, 48, 6951.0, 'D', 'In Debt - Contract Running')
# (7051, 10068, 970728, 77808, 12, 6484.0, 'A', 'Good - Contract Finished')
# (6758, 8742, 970729, 33144, 12, 2762.0, 'A', 'Good - Contract Finished')
# (6249, 6138, 970730, 67608, 24, 2817.0, 'C', 'Good - Contract Running')
# (5808, 4099, 970731, 41856, 48, 872.0, 'C', 'Good - Contract Running')
# (5377, 2116, 970804, 92400, 12, 7700.0, 'A', 'Good - Contract Finished')
# (5446, 2334, 970804, 48312, 24, 2013.0, 'C', 'Good - Contract Running')
# (5856, 4320, 970809, 51360, 12, 4280.0, 'B', 'Defaulter - Contract Finished')
# (4986, 97, 970810, 102876, 12, 8573.0, 'A', 'Good - Contract Finished')
# (7001, 9859, 970810, 300600, 60, 5010.0, 'C', 'Good - Contract Running')
# (6677, 8169, 970812, 97980, 60, 1633.0, 'C', 'Good - Contract Running')
# (6665, 8114, 970815, 99300, 60, 1655.0, 'C', 'Good - Contract Running')
# (5817, 4127, 970815, 100800, 24, 4200.0, 'D', 'In Debt - Contract Running')
# (6984, 9730, 970815, 116040, 60, 1934.0, 'C', 'Good - Contract Running')
# (6541, 7565, 970817, 153504, 48, 3198.0, 'C', 'Good - Contract Running')
# (5117, 718, 970820, 76944, 12, 6412.0, 'A', 'Good - Contract Finished')
# (6097, 5362, 970821, 202848, 48, 4226.0, 'C', 'Good - Contract Running')
# (5389, 2165, 970822, 78600, 24, 3275.0, 'C', 'Good - Contract Running')
# (7219, 10905, 970823, 57120, 48, 1190.0, 'C', 'Good - Contract Running')
# (6338, 6592, 970824, 390660, 60, 6511.0, 'C', 'Good - Contract Running')
# (6922, 9424, 970826, 83628, 36, 2323.0, 'C', 'Good - Contract Running')
# (5367, 2064, 970826, 83628, 36, 2323.0, 'C', 'Good - Contract Running')
# (5638, 3249, 970827, 68124, 12, 5677.0, 'A', 'Good - Contract Finished')
# (5830, 4190, 970828, 405780, 60, 6763.0, 'C', 'Good - Contract Running')
# (5338, 1888, 970830, 57360, 12, 4780.0, 'B', 'Defaulter - Contract Finished')
# (6007, 4949, 970830, 289920, 48, 6040.0, 'C', 'Good - Contract Running')
# (6612, 7907, 970831, 97392, 12, 8116.0, 'A', 'Good - Contract Finished')
# (5718, 3637, 970901, 14028, 12, 1169.0, 'A', 'Good - Contract Finished')
# (6104, 5395, 970905, 158184, 36, 4394.0, 'C', 'Good - Contract Running')
# (5229, 1329, 970906, 23520, 12, 1960.0, 'A', 'Good - Contract Finished')
# (6625, 7966, 970907, 473280, 60, 7888.0, 'D', 'In Debt - Contract Running')
# (5206, 1242, 970907, 128544, 24, 5356.0, 'C', 'Good - Contract Running')
# (5963, 4746, 970907, 204780, 60, 3413.0, 'C', 'Good - Contract Running')
# (4990, 110, 970908, 162576, 36, 4516.0, 'C', 'Good - Contract Running')
# (6641, 8026, 970909, 128268, 36, 3563.0, 'C', 'Good - Contract Running')
# (5369, 2080, 970912, 214596, 36, 5961.0, 'C', 'Good - Contract Running')
# (6196, 5837, 970914, 177804, 36, 4939.0, 'C', 'Good - Contract Running')
# (5236, 1374, 970915, 389136, 48, 8107.0, 'C', 'Good - Contract Running')
# (5719, 3664, 970920, 271584, 48, 5658.0, 'C', 'Good - Contract Running')
# (5643, 3273, 970921, 94512, 12, 7876.0, 'B', 'Defaulter - Contract Finished')
# (7050, 10065, 970923, 311232, 48, 6484.0, 'C', 'Good - Contract Running')
# (6355, 6699, 970924, 127200, 48, 2650.0, 'C', 'Good - Contract Running')
# (6688, 8268, 970926, 8616, 24, 359.0, 'C', 'Good - Contract Running')
# (6239, 6083, 970928, 360864, 48, 7518.0, 'D', 'In Debt - Contract Running')
# (5531, 2753, 970930, 66432, 24, 2768.0, 'C', 'Good - Contract Running')
# (6113, 5445, 971001, 78696, 36, 2186.0, 'C', 'Good - Contract Running')
# (7181, 10679, 971002, 197808, 24, 8242.0, 'C', 'Good - Contract Running')
# (6118, 5477, 971004, 349392, 48, 7279.0, 'C', 'Good - Contract Running')
# (7264, 11141, 971007, 44940, 12, 3745.0, 'A', 'Good - Contract Finished')
# (5343, 1906, 971008, 44952, 24, 1873.0, 'C', 'Good - Contract Running')
# (5051, 378, 971011, 230400, 60, 3840.0, 'C', 'Good - Contract Running')
# (5779, 3942, 971014, 107352, 36, 2982.0, 'C', 'Good - Contract Running')
# (6605, 7890, 971014, 79344, 48, 1653.0, 'C', 'Good - Contract Running')
# (6655, 8085, 971017, 260400, 60, 4340.0, 'D', 'In Debt - Contract Running')
# (6534, 7542, 971019, 590820, 60, 9847.0, 'C', 'Good - Contract Running')
# (5681, 3448, 971020, 68664, 24, 2861.0, 'C', 'Good - Contract Running')
# (6607, 7894, 971021, 153144, 36, 4254.0, 'C', 'Good - Contract Running')
# (6242, 6097, 971022, 26208, 36, 728.0, 'C', 'Good - Contract Running')
# (7242, 11027, 971023, 48096, 24, 2004.0, 'C', 'Good - Contract Running')
# (7277, 11231, 971024, 89280, 12, 7440.0, 'A', 'Good - Contract Finished')
# (6675, 8158, 971101, 238716, 36, 6631.0, 'C', 'Good - Contract Running')
# (5398, 2187, 971104, 53472, 12, 4456.0, 'A', 'Good - Contract Finished')
# (5956, 4725, 971104, 168264, 36, 4674.0, 'C', 'Good - Contract Running')
# (5731, 3711, 971105, 460980, 60, 7683.0, 'D', 'In Debt - Contract Running')
# (6956, 9631, 971109, 59448, 24, 2477.0, 'C', 'Good - Contract Running')
# (6437, 7052, 971109, 63972, 36, 1777.0, 'D', 'In Debt - Contract Running')
# (5447, 2335, 971112, 541200, 60, 9020.0, 'D', 'In Debt - Contract Running')
# (5973, 4784, 971124, 219456, 48, 4572.0, 'C', 'Good - Contract Running')
# (6075, 5267, 971126, 129312, 24, 5388.0, 'D', 'In Debt - Contract Running')
# (5281, 1580, 971127, 194256, 24, 8094.0, 'C', 'Good - Contract Running')
# (5103, 666, 971128, 12540, 12, 1045.0, 'A', 'Good - Contract Finished')
# (6468, 7176, 971130, 203940, 60, 3399.0, 'C', 'Good - Contract Running')
# (7209, 10857, 971130, 385560, 60, 6426.0, 'D', 'In Debt - Contract Running')
# (5584, 2986, 971206, 24792, 24, 1033.0, 'C', 'Good - Contract Running')
# (4988, 103, 971206, 265320, 36, 7370.0, 'D', 'In Debt - Contract Running')
# (6502, 7424, 971208, 30276, 12, 2523.0, 'A', 'Good - Contract Finished')
# (5651, 3329, 971208, 19248, 12, 1604.0, 'A', 'Good - Contract Finished')
# (4962, 25, 971208, 30276, 12, 2523.0, 'A', 'Good - Contract Finished')
# (5862, 4342, 971209, 100128, 24, 4172.0, 'C', 'Good - Contract Running')
# (7199, 10789, 971209, 45768, 12, 3814.0, 'A', 'Good - Contract Finished')
# (6727, 8505, 971210, 42840, 12, 3570.0, 'A', 'Good - Contract Finished')
# (7279, 11244, 971211, 155760, 24, 6490.0, 'C', 'Good - Contract Running')
# (6544, 7594, 971211, 130464, 48, 2718.0, 'C', 'Good - Contract Running')
# (5933, 4631, 971213, 87528, 24, 3647.0, 'C', 'Good - Contract Running')
# (6574, 7745, 971220, 77544, 36, 2154.0, 'C', 'Good - Contract Running')
# (6399, 6902, 971221, 49320, 36, 1370.0, 'C', 'Good - Contract Running')
# (7187, 10711, 971224, 24180, 60, 403.0, 'C', 'Good - Contract Running')
# (6353, 6686, 971225, 116496, 24, 4854.0, 'C', 'Good - Contract Running')
# (5043, 339, 971225, 468060, 60, 7801.0, 'C', 'Good - Contract Running')
# (5469, 2445, 971226, 293160, 60, 4886.0, 'C', 'Good - Contract Running')
# (5976, 4794, 971227, 465504, 48, 9698.0, 'D', 'In Debt - Contract Running')
# (6059, 5196, 971228, 79824, 12, 6652.0, 'A', 'Good - Contract Finished')
# (5799, 4052, 971228, 106128, 36, 2948.0, 'C', 'Good - Contract Running')
# (6147, 5602, 971228, 177504, 48, 3698.0, 'C', 'Good - Contract Running')
# (6254, 6157, 971228, 247920, 48, 5165.0, 'C', 'Good - Contract Running')
# (7100, 10280, 971231, 348120, 60, 5802.0, 'C', 'Good - Contract Running')
# (7147, 10478, 980102, 267600, 48, 5575.0, 'C', 'Good - Contract Running')
# (5909, 4550, 980103, 61320, 60, 1022.0, 'C', 'Good - Contract Running')
# (7037, 10022, 980103, 218064, 48, 4543.0, 'C', 'Good - Contract Running')
# (5782, 3953, 980104, 63576, 12, 5298.0, 'C', 'Good - Contract Running')
# (6237, 6075, 980106, 407952, 48, 8499.0, 'D', 'In Debt - Contract Running')
# (6552, 7632, 980108, 170448, 48, 3551.0, 'C', 'Good - Contract Running')
# (7067, 10134, 980111, 136368, 24, 5682.0, 'C', 'Good - Contract Running')
# (5320, 1819, 980111, 143676, 36, 3991.0, 'C', 'Good - Contract Running')
# (5930, 4616, 980112, 66696, 24, 2779.0, 'C', 'Good - Contract Running')
# (6486, 7240, 980115, 152160, 60, 2536.0, 'C', 'Good - Contract Running')
# (5245, 1407, 980117, 125472, 24, 5228.0, 'C', 'Good - Contract Running')
# (6643, 8038, 980118, 35856, 24, 1494.0, 'C', 'Good - Contract Running')
# (5260, 1480, 980119, 123300, 36, 3425.0, 'C', 'Good - Contract Running')
# (5569, 2936, 980120, 504000, 60, 8400.0, 'C', 'Good - Contract Running')
# (7110, 10345, 980121, 31260, 12, 2605.0, 'C', 'Good - Contract Running')
# (7139, 10445, 980122, 23412, 12, 1951.0, 'C', 'Good - Contract Running')
# (6791, 8926, 980123, 566640, 60, 9444.0, 'C', 'Good - Contract Running')
# (5360, 2035, 980125, 176328, 36, 4898.0, 'C', 'Good - Contract Running')
# (5287, 1638, 980126, 64224, 24, 2676.0, 'C', 'Good - Contract Running')
# (6553, 7636, 980126, 42384, 12, 3532.0, 'C', 'Good - Contract Running')
# (7072, 10148, 980127, 22104, 12, 1842.0, 'C', 'Good - Contract Running')
# (6044, 5133, 980127, 57060, 12, 4755.0, 'C', 'Good - Contract Running')
# (5332, 1869, 980129, 37944, 36, 1054.0, 'C', 'Good - Contract Running')
# (6866, 9201, 980205, 122472, 24, 5103.0, 'C', 'Good - Contract Running')
# (6633, 7997, 980205, 160656, 24, 6694.0, 'C', 'Good - Contract Running')
# (6926, 9455, 980207, 374760, 60, 6246.0, 'C', 'Good - Contract Running')
# (6442, 7082, 980208, 194160, 48, 4045.0, 'C', 'Good - Contract Running')
# (5889, 4456, 980209, 321240, 60, 5354.0, 'C', 'Good - Contract Running')
# (5765, 3875, 980210, 153936, 24, 6414.0, 'C', 'Good - Contract Running')
# (5124, 785, 980212, 156096, 36, 4336.0, 'C', 'Good - Contract Running')
# (5491, 2545, 980213, 428784, 48, 8933.0, 'C', 'Good - Contract Running')
# (6730, 8523, 980215, 93036, 12, 7753.0, 'C', 'Good - Contract Running')
# (7151, 10493, 980218, 133800, 24, 5575.0, 'C', 'Good - Contract Running')
# (5140, 873, 980224, 178500, 60, 2975.0, 'C', 'Good - Contract Running')
# (7171, 10650, 980224, 196224, 48, 4088.0, 'C', 'Good - Contract Running')
# (6568, 7713, 980225, 220440, 60, 3674.0, 'C', 'Good - Contract Running')
# (6861, 9179, 980228, 215040, 60, 3584.0, 'C', 'Good - Contract Running')
# (6855, 9153, 980301, 52236, 36, 1451.0, 'C', 'Good - Contract Running')
# (7129, 10404, 980301, 194280, 60, 3238.0, 'C', 'Good - Contract Running')
# (5384, 2142, 980307, 23328, 12, 1944.0, 'C', 'Good - Contract Running')
# (6859, 9167, 980307, 272220, 60, 4537.0, 'C', 'Good - Contract Running')
# (5772, 3906, 980308, 334620, 60, 5577.0, 'C', 'Good - Contract Running')
# (5665, 3390, 980311, 40632, 12, 3386.0, 'C', 'Good - Contract Running')
# (6495, 7274, 980312, 49044, 12, 4087.0, 'C', 'Good - Contract Running')
# (5061, 440, 980313, 84288, 48, 1756.0, 'C', 'Good - Contract Running')
# (6948, 9560, 980315, 157068, 36, 4363.0, 'C', 'Good - Contract Running')
# (5773, 3907, 980316, 133848, 24, 5577.0, 'C', 'Good - Contract Running')
# (6052, 5164, 980323, 22356, 36, 621.0, 'C', 'Good - Contract Running')
# (6682, 8225, 980330, 36204, 12, 3017.0, 'D', 'In Debt - Contract Running')
# (6083, 5305, 980331, 240528, 48, 5011.0, 'C', 'Good - Contract Running')
# (6962, 9646, 980402, 279072, 48, 5814.0, 'C', 'Good - Contract Running')
# (5158, 1004, 980411, 188532, 36, 5237.0, 'C', 'Good - Contract Running')
# (6464, 7156, 980416, 49488, 24, 2062.0, 'C', 'Good - Contract Running')
# (5172, 1083, 980416, 50976, 36, 1416.0, 'C', 'Good - Contract Running')
# (5582, 2982, 980417, 41256, 12, 3438.0, 'C', 'Good - Contract Running')
# (6136, 5572, 980419, 140880, 60, 2348.0, 'C', 'Good - Contract Running')
# (6235, 6062, 980419, 321360, 60, 5356.0, 'C', 'Good - Contract Running')
# (6508, 7437, 980419, 110736, 48, 2307.0, 'C', 'Good - Contract Running')
# (4968, 38, 980419, 110736, 48, 2307.0, 'C', 'Good - Contract Running')
# (6632, 7990, 980423, 144960, 48, 3020.0, 'C', 'Good - Contract Running')
# (7195, 10774, 980423, 339168, 48, 7066.0, 'C', 'Good - Contract Running')
# (5525, 2720, 980427, 93888, 36, 2608.0, 'C', 'Good - Contract Running')
# (6320, 6495, 980428, 104964, 12, 8747.0, 'C', 'Good - Contract Running')
# (6766, 8784, 980428, 74352, 24, 3098.0, 'C', 'Good - Contract Running')
# (6872, 9227, 980429, 191580, 60, 3193.0, 'C', 'Good - Contract Running')
# (5906, 4533, 980505, 81144, 36, 2254.0, 'C', 'Good - Contract Running')
# (7172, 10652, 980507, 45720, 12, 3810.0, 'C', 'Good - Contract Running')
# (6571, 7733, 980512, 140064, 24, 5836.0, 'C', 'Good - Contract Running')
# (5616, 3143, 980515, 130896, 24, 5454.0, 'C', 'Good - Contract Running')
# (6312, 6453, 980517, 10944, 36, 304.0, 'C', 'Good - Contract Running')
# (6470, 7181, 980517, 49872, 12, 4156.0, 'C', 'Good - Contract Running')
# (5147, 938, 980521, 22260, 60, 371.0, 'C', 'Good - Contract Running')
# (5501, 2622, 980521, 136344, 24, 5681.0, 'C', 'Good - Contract Running')
# (6436, 7049, 980522, 495180, 60, 8253.0, 'C', 'Good - Contract Running')
# (5699, 3562, 980524, 174960, 24, 7290.0, 'C', 'Good - Contract Running')
# (5313, 1776, 980527, 43200, 24, 1800.0, 'C', 'Good - Contract Running')
# (6234, 6061, 980528, 5148, 12, 429.0, 'C', 'Good - Contract Running')
# (6569, 7721, 980528, 45456, 12, 3788.0, 'C', 'Good - Contract Running')
# (7202, 10812, 980529, 140688, 48, 2931.0, 'C', 'Good - Contract Running')
# (5683, 3460, 980529, 140688, 48, 2931.0, 'C', 'Good - Contract Running')
# (5034, 303, 980530, 112752, 36, 3132.0, 'C', 'Good - Contract Running')
# (5435, 2279, 980601, 314688, 48, 6556.0, 'C', 'Good - Contract Running')
# (5815, 4116, 980603, 151200, 36, 4200.0, 'C', 'Good - Contract Running')
# (5589, 3005, 980605, 390000, 48, 8125.0, 'C', 'Good - Contract Running')
# (6746, 8639, 980606, 185640, 60, 3094.0, 'C', 'Good - Contract Running')
# (6790, 8919, 980608, 76104, 24, 3171.0, 'C', 'Good - Contract Running')
# (6857, 9159, 980608, 69600, 48, 1450.0, 'C', 'Good - Contract Running')
# (6450, 7099, 980610, 234336, 48, 4882.0, 'C', 'Good - Contract Running')
# (7221, 10915, 980611, 152460, 60, 2541.0, 'C', 'Good - Contract Running')
# (5527, 2728, 980615, 156420, 60, 2607.0, 'C', 'Good - Contract Running')
# (5620, 3161, 980616, 30012, 12, 2501.0, 'C', 'Good - Contract Running')
# (6215, 5944, 980618, 78720, 48, 1640.0, 'C', 'Good - Contract Running')
# (7167, 10644, 980618, 269964, 36, 7499.0, 'C', 'Good - Contract Running')
# (5823, 4144, 980621, 212976, 36, 5916.0, 'C', 'Good - Contract Running')
# (6207, 5912, 980623, 184620, 60, 3077.0, 'C', 'Good - Contract Running')
# (6932, 9491, 980625, 225504, 48, 4698.0, 'C', 'Good - Contract Running')
# (5669, 3403, 980627, 71820, 36, 1995.0, 'C', 'Good - Contract Running')
# (5154, 993, 980701, 108720, 60, 1812.0, 'C', 'Good - Contract Running')
# (7168, 10645, 980705, 208332, 36, 5787.0, 'C', 'Good - Contract Running')
# (5585, 2988, 980708, 88608, 12, 7384.0, 'C', 'Good - Contract Running')
# (7200, 10799, 980711, 31140, 60, 519.0, 'C', 'Good - Contract Running')
# (6539, 7559, 980711, 12792, 12, 1066.0, 'C', 'Good - Contract Running')
# (5774, 3916, 980712, 96984, 36, 2694.0, 'C', 'Good - Contract Running')
# (6357, 6706, 980712, 64860, 60, 1081.0, 'C', 'Good - Contract Running')
# (5042, 330, 980712, 331584, 48, 6908.0, 'C', 'Good - Contract Running')
# (5015, 226, 980712, 109344, 12, 9112.0, 'C', 'Good - Contract Running')
# (5354, 2000, 980714, 290820, 60, 4847.0, 'C', 'Good - Contract Running')
# (6054, 5180, 980716, 58764, 12, 4897.0, 'C', 'Good - Contract Running')
# (7295, 11328, 980718, 280440, 60, 4674.0, 'C', 'Good - Contract Running')
# (5365, 2055, 980719, 271260, 60, 4521.0, 'C', 'Good - Contract Running')
# (6755, 8713, 980724, 170700, 60, 2845.0, 'C', 'Good - Contract Running')
# (5991, 4858, 980727, 335184, 48, 6983.0, 'D', 'In Debt - Contract Running')
# (7035, 10005, 980729, 210744, 36, 5854.0, 'C', 'Good - Contract Running')
# (5893, 4467, 980803, 86184, 36, 2394.0, 'C', 'Good - Contract Running')
# (7164, 10613, 980815, 249792, 48, 5204.0, 'C', 'Good - Contract Running')
# (5304, 1718, 980820, 172272, 24, 7178.0, 'C', 'Good - Contract Running')
# (5561, 2910, 980829, 437460, 60, 7291.0, 'C', 'Good - Contract Running')
# (5520, 2699, 980830, 231168, 48, 4816.0, 'C', 'Good - Contract Running')
# (5241, 1389, 980902, 125472, 24, 5228.0, 'C', 'Good - Contract Running')
# (7096, 10257, 980902, 37812, 12, 3151.0, 'C', 'Good - Contract Running')
# (6078, 5283, 980909, 170832, 48, 3559.0, 'C', 'Good - Contract Running')
# (5046, 349, 980909, 42816, 12, 3568.0, 'C', 'Good - Contract Running')
# (5334, 1876, 980910, 209040, 24, 8710.0, 'C', 'Good - Contract Running')
# (6969, 9673, 980912, 88200, 36, 2450.0, 'C', 'Good - Contract Running')
# (6821, 9037, 980915, 321936, 48, 6707.0, 'C', 'Good - Contract Running')
# (5760, 3862, 980918, 74916, 36, 2081.0, 'C', 'Good - Contract Running')
# (5614, 3137, 980921, 253560, 60, 4226.0, 'C', 'Good - Contract Running')
# (7091, 10243, 980922, 113436, 36, 3151.0, 'C', 'Good - Contract Running')
# (5698, 3556, 980922, 174840, 60, 2914.0, 'C', 'Good - Contract Running')
# (5169, 1068, 980924, 253200, 60, 4220.0, 'C', 'Good - Contract Running')
# (7294, 11327, 980927, 39168, 24, 1632.0, 'C', 'Good - Contract Running')
# (5318, 1808, 980930, 385584, 48, 8033.0, 'C', 'Good - Contract Running')
# (5368, 2073, 981005, 44640, 24, 1860.0, 'C', 'Good - Contract Running')
# (6923, 9433, 981005, 44640, 24, 1860.0, 'C', 'Good - Contract Running')
# (5463, 2413, 981006, 17952, 12, 1496.0, 'C', 'Good - Contract Running')
# (5265, 1498, 981007, 165780, 60, 2763.0, 'C', 'Good - Contract Running')
# (6321, 6505, 981008, 38496, 12, 3208.0, 'C', 'Good - Contract Running')
# (5226, 1318, 981011, 185544, 36, 5154.0, 'C', 'Good - Contract Running')
# (6868, 9208, 981012, 82128, 24, 3422.0, 'C', 'Good - Contract Running')
# (4967, 37, 981014, 318480, 60, 5308.0, 'D', 'In Debt - Contract Running')
# (5293, 1656, 981029, 189792, 48, 3954.0, 'C', 'Good - Contract Running')
# (5865, 4354, 981030, 327660, 60, 5461.0, 'C', 'Good - Contract Running')
# (5841, 4268, 981104, 41988, 12, 3499.0, 'C', 'Good - Contract Running')
# (5526, 2725, 981108, 69624, 36, 1934.0, 'C', 'Good - Contract Running')
# (6852, 9140, 981110, 16032, 48, 334.0, 'C', 'Good - Contract Running')
# (6469, 7180, 981117, 99744, 24, 4156.0, 'C', 'Good - Contract Running')
# (6168, 5698, 981121, 99216, 36, 2756.0, 'C', 'Good - Contract Running')
# (7292, 11317, 981122, 317460, 60, 5291.0, 'C', 'Good - Contract Running')
# (5036, 309, 981125, 91248, 48, 1901.0, 'C', 'Good - Contract Running')
# (5644, 3293, 981127, 276084, 36, 7669.0, 'C', 'Good - Contract Running')
# (6856, 9156, 981201, 163332, 36, 4537.0, 'C', 'Good - Contract Running')
# (5428, 2262, 981202, 230220, 36, 6395.0, 'C', 'Good - Contract Running')
# (5027, 276, 981202, 160920, 36, 4470.0, 'C', 'Good - Contract Running')
# (4989, 105, 981205, 352704, 48, 7348.0, 'C', 'Good - Contract Running')
# (5221, 1284, 981205, 52512, 12, 4376.0, 'C', 'Good - Contract Running')
# (6402, 6922, 981206, 139488, 24, 5812.0, 'C', 'Good - Contract Running')
# (5346, 1928, 981206, 55632, 24, 2318.0, 'C', 'Good - Contract Running')
# (6748, 8645, 981208, 240900, 60, 4015.0, 'C', 'Good - Contract Running')
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Creating other databases in our MySQL

# %%
# Running other queries in SQL

engine.execute("DROP DATABASE IF EXISTS BootCamps")
engine.execute("CREATE DATABASE IF NOT EXISTS BootCamps")
engine.execute("USE BootCamps")

# %% [markdown]
# ## Getting a Panda's dataframe (df) called "data" out of a MySQL query

# %%
engine.execute("USE bank")
query = 'select order_id as "OrderID", account_id as "AccountID", bank_to as "DestinationBank", amount  as "Amount" \
from bank.order \
where k_symbol = "SIPO" \
limit 100'
data = pd.read_sql_query(query, engine)
data.head()
# Out:
#    OrderID  AccountID DestinationBank  Amount
# 0    29401          1              YZ  2452.0
# 1    29403          2              QR  7266.0
# 2    29404          3              WX  1135.0
# 3    29407          4              UV  2078.0
# 4    29408          4              UV  1285.0

# %% [markdown]
# # Lesson 2 Key Concepts

# %% [markdown]
# How we can get the data?

# %%
query = "select * from bank.trans t \
left join bank.loan l \
on t.account_id = l.account_id \
where l.status in ('A', 'B')"

data = pd.read_sql_query(query, engine)
data.head()
# Out:
#    trans_id  account_id    date    type      operation   amount  balance  \
# 0   1548750        5270  930114  PRIJEM  PREVOD Z UCTU  44749.0  45549.0
# 1   3393738       11265  930114  PRIJEM          VKLAD   1000.0   1000.0
# 2   3122924       10364  930117  PRIJEM          VKLAD   1100.0   1100.0
# 3   1121963        3834  930119  PRIJEM          VKLAD    700.0    700.0
# 4   2809952        9307  930124  PRIJEM          VKLAD    900.0    900.0
#
#   k_symbol bank   account  loan_id  account_id    date  amount  duration  \
# 0            IJ  80269753     6077        5270  931122   79608        24
# 1                       0     7284       11265  930915   52788        12
# 2                       0     7121       10364  931110   21924        36
# 3                       0     5754        3834  940928   23052        12
# 4                       0     6895        9307  940919   41904        12
#
#    payments status               status_desc
# 0    3317.0      A  Good - Contract Finished
# 1    4399.0      A  Good - Contract Finished
# 2     609.0      A  Good - Contract Finished
# 3    1921.0      A  Good - Contract Finished
# 4    3492.0      A  Good - Contract Finished

# %% [markdown]
# # Lesson 3 Key Concepts

# %% [markdown]
# ## Getting our data

# %%
# Extracting the data 

query = "select t.type, t.operation, t.amount as t_amount, t.balance, t.k_symbol, \
l.amount as l_amount, l.duration, l.payments, l.status from bank.trans t \
left join bank.loan l \
on t.account_id = l.account_id \
where l.status in ('A', 'B')"
data = pd.read_sql_query(query, engine)
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d2afdd2db52> in <module>
#       6 on t.account_id = l.account_id \
#       7 where l.status in ('A', 'B')"
# ----> 8 data = pd.read_sql_query(query, engine)
#       9 data.head()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Data exploration

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="whitegrid")

# %% [markdown]
# ### Knowing the shape and the column types of your dataframe

# %%
print("The dataframe has {} rows and {} columns".format(data.shape[0],data.shape[1]))
print()
print("The data types of each column of the dataframe are:")
print(data.dtypes)
print()

# %% [markdown]
# ### Fixing the type of column duration to categorical (nominal)

# %%
data['duration'] = data['duration'].astype('str')
data['duration'] = data['duration'].astype('object') # This will be treated as categorical (ordinal)

# %% [markdown]
# ### Getting basic statistical summary of the numerical columns

# %%
data.describe()

# %% [markdown]
# ### Looking for NA's

# %%
print("The number of NA's in the dataframe is: ")
print(data.isna().sum())
print()

# %% [markdown]
# "Aparently" the are not missing values, but already know how nasty the SQL's NULLS are!

# %% [markdown]
# ## Categorical columns

# %%
## checking all the categorical columns
cols_cat = list(data.select_dtypes(include=['object']).columns)

print("The categorical columns are: ",cols_cat)
print("========================================")
print()

for col in cols_cat:
    print("Frequency analysis of column: ",col)
    my_data = data[col].value_counts().reset_index()
    ax = sns.barplot(x=col, y="index", data = my_data).set_title(col.upper())
    plt.figure()
    print()

# %% [markdown]
# ### Replacing missing values in column "operation"

# %%
# since we have a lot values for operation which are of type vyber,
# we are not removing that data from type column

def cleanOperation(x):
    x = x.lower()
    if 'vyber' in x:
        return "vyber"
    elif 'prevod' in x:
        return "prevod"
    elif 'vklad' in x:
        return 'vklad'
    else:
        return 'unknown'

data['operation'] = list(map(cleanOperation, data['operation']))
data['operation'].value_counts()

# %% [markdown]
# ### Replacing missing values in column "k_symbol"

# %%
print("Current frequencies of of each value in column 'k_symbol': ",data['k_symbol'].value_counts())
print(data['k_symbol'].value_counts().index)

def cleankSymbol(x):
    if x in ['', ' ']:
        return 'unknown'
    else:
        return x

data['k_symbol'] = list(map(cleankSymbol, data['k_symbol']))
print("Final frequencies of of each value in column 'k_symbol': ",data['k_symbol'].value_counts())

# %% [markdown]
# As we have too much "unknowns" and we don't know how to impute them. We drop such rows form the dataframe

# %%
data = data[~data['k_symbol'].isin(['POJISTINE', 'SANKC. UROK', 'UVER'])]
data['k_symbol'].value_counts()

# %% [markdown]
# ### Replacing values in column "duration"

# %%
data['duration'].value_counts().index

def cleanDuration(x):
    if x in ['48', '60']:
        return 'other'
    else:
        return str(x)
data['duration'] = list(map(cleanDuration, data['duration']))
data['duration'].value_counts()

# %% [markdown]
# ### Dummifying categorical columns

# %%
cat = data.select_dtypes(include = np.object)
cat = cat.drop(['status'], axis=1)
categorical = pd.get_dummies(cat, columns=['type', 'operation', 'k_symbol', 'duration'],drop_first=True)
categorical.head()

# %% [markdown]
# ## Numerical columns

# %% [markdown]
# ### Checking for multicollinearity

# %%
corr_matrix=data.corr(method='pearson')  # default
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# **Remember that multicollinearity is not a problem in a logistic model**

# %% [markdown]
# ### Getting distributions of numericals

# %%
sns.displot(data['t_amount'])
plt.show()

sns.displot(data['l_amount'])
plt.show()

sns.displot(data['balance'])
plt.show()

sns.displot(data['payments'])
plt.show()

# %% [markdown]
# High skewness!!! Specially for "t_amount". With a **linnear model we can't use them as they are**.
# With a **logistic model YES**, but it will help a lot to get a better model.

# %% [markdown]
# ### Transforming numerical columns with different transformers

# %%
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler

X = data.select_dtypes(include = np.number)

X1 = X.copy()
X2 = X.copy()

# %% [markdown]
# #### Normalizer

# %%
# Normalizing data
transformer = Normalizer().fit(X1)
x_normalized = transformer.transform(X1)
x_normalized = pd.DataFrame(x_normalized)

# %%
### Standarizer
transformer = StandardScaler().fit(X2)
x_standarized = transformer.transform(X2)
x_standarized = pd.DataFrame(x_standarized)

# %% [markdown]
# # Lesson 4 Key Concepts

# %%
## Model 1: Independent variables normalized

# %%
y = data['status']
X = np.concatenate((x_normalized, categorical), axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=100)

# %%
from sklearn.linear_model import LogisticRegression

classification = LogisticRegression(random_state=0, solver='lbfgs',
                  multi_class='ovr').fit(X_train, y_train)

# %%
y = data['status']
X = np.concatenate((x_standarized, categorical), axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=100)

# %%
classification = LogisticRegression(random_state=0, solver='lbfgs',
                  multi_class='ovr').fit(X_train, y_train)

# %%
from sklearn.metrics import accuracy_score

predictions = classification.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import cohen_kappa_score

print("The accuracy of the model on test set is: %4.2f " % accuracy_score(y_test, predictions))
print(confusion_matrix(y_test, predictions))
plot_confusion_matrix(classification, X_test, y_test)  # doctest: +SKIP
plt.show()  # doctest: +SKIP
print("The Kappa of your model is: %4.2f" % (cohen_kappa_score(y_test, predictions)))
