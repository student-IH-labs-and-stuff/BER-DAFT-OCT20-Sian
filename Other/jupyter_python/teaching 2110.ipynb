# %%
import numpy as np

# %%
import pandas as pd

# %%
file1 = pd.read_csv('file1.csv')

# %%
file1.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0     44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1     96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2     43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL      F   995.00  252  348.0     0  17991      5      6
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0

# %%
file2 = pd.read_csv('file2.txt',sep='\t')

# %%
file2.head()
# Out:
#    CONTROLN STATE   GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    190579    CA        M  3200  310  343    83  17224     31     32  311
# 1     42997    FL        F  1567  392  409    27  18631      4     10  391
# 2    132896    OR        F   953  319  455     1  15729      3     45  379
# 3    120189    TX        M   492  244  301     3  10818      0     92  260
# 4    138829    AZ  feamale   847  185  308     0  11582      3     20  238
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  333   3.106061      1     0     U1       4.0
# 1  434   6.562500      2  1808     C1       7.0
# 2  387  15.571429      2  4410     T1      25.0
# 3  284  19.375000      0     0     T2      25.0
# 4  225  11.500000     28  3601     T2      25.0

# %%
file2.shape
# Out:
# (1015, 17)

# %%
file1.shape
# Out:
# (1007, 17)

# %%
column_names=file1.columns

# %%
data=pd.DataFrame(columns=column_names)

# %%
data.head()
# Out:
# Empty DataFrame
# Columns: [CONTROLN, STATE, GENDER, HV1, IC1, IC4, HVP1, IC5, POBC1, POBC2, IC2, IC3, AVGGIFT, TCODE, DOB, DOMAIN, TARGET_D]
# Index: []

# %%
data=pd.concat([data,file1],axis=0)

# %%
data.head()
# Out:
#   CONTROLN STATE GENDER      HV1  IC1    IC4 HVP1    IC5 POBC1 POBC2    IC2  \
# 0    44060    FL      M   AAA896  392  520.0    7  21975     6    16  430.0
# 1    96093    IL      M   537.00  365  473.0    0  19387     1    89  415.0
# 2    43333    FL      F   725.00  301  436.0    3  18837    11    17  340.0
# 3    21885    NC      M  AAA1095  401  413.0    7  14014     1    74  407.0
# 4   190108    FL      F   995.00  252  348.0    0  17991     5     6  280.0
#
#    IC3    AVGGIFT TCODE   DOB DOMAIN  TARGET_D
# 0  466  28.000000     1  1901     C2     100.0
# 1  410   5.666667     0     0     T2       7.0
# 2  361   4.111111     0  2501     C2       5.0
# 3  399  27.277778     0  2208     T2      38.0
# 4  316   6.000000    28     0     C2       5.0

# %%
data=pd.concat([data,file2],axis=0)

# %%
data.shape
# Out:
# (2022, 17)

# %%
data.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
data.columns =data.columns.str.lower()

# %%
file3 = pd.read_excel('file3.xlsx')

# %%
file4 = pd.read_excel('file4.xlsx')

# %%
file3.head()
# Out:
#    CONTROLN      STATE GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    119966         TX      F   321  225  281     0   9372      3     68  264
# 1    152470         CA      F  5725  610  807    97  53158     13     22  763
# 2     48527         AL   Male   931  407  496     0  17743      0     65  502
# 3    171528         CA      F  1895  317  471    46  17431     10     62  389
# 4     50122  Tennessee      F   715  318  370     2  12416      0     75  340
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  243   8.058824      0  3212     T3      11.0
# 1  698  23.727273      0     0     S1      45.0
# 2  439   4.416667      2     0     R3       3.0
# 3  405   6.705882      0  5501     R2       5.0
# 4  352   9.250000      2     0     T1      10.0

# %%
file4.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    186307    CA      M  AAA1229  345  438     3  15915      2     58  388
# 1     34174    WV      F      529  198  291     0  10816      0     80  218
# 2    101388    MO      M      526  340  342     0   9687      0     89  348
# 3    159472    CA      F      621  231  279     0   6184     43     41  237
# 4    179143    WA   male     1688  496  564    35  22963      2     63  520
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  417  16.142857      1  2511     C2      20.0
# 1  257   6.083333      2  3001     T2      12.0
# 2  321   5.800000      1  5501     R2      10.0
# 3  272  11.666667      1  1512     R3      15.0
# 4  521  23.900000      1  3709     T1      25.0

# %%
data=pd.concat([data,file3],axis=0)

# %%
file3.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
data=pd.concat([data,file4],axis=0)

# %%
data.shape
# Out:
# (4028, 34)

# %%
data = data.drop(['domain'],axis=1)

# %%
data.columns
# Out:
# Index(['controln', 'state', 'gender', 'hv1', 'ic1', 'ic4', 'hvp1', 'ic5',
#        'pobc1', 'pobc2', 'ic2', 'ic3', 'avggift', 'tcode', 'dob', 'target_d',
#        'CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
data=data[['controln', 'state', 'gender', 'hv1', 'hvp1',
       'pobc1', 'pobc2','avggift', 'tcode', 'target_d','ic1','ic2','ic3','ic4','ic5']]

# %%
data.head()
# Out:
#   controln state gender      hv1 hvp1 pobc1 pobc2    avggift tcode  target_d  \
# 0    44060    FL      M   AAA896    7     6    16  28.000000     1     100.0
# 1    96093    IL      M   537.00    0     1    89   5.666667     0       7.0
# 2    43333    FL      F   725.00    3    11    17   4.111111     0       5.0
# 3    21885    NC      M  AAA1095    7     1    74  27.277778     0      38.0
# 4   190108    FL      F   995.00    0     5     6   6.000000    28       5.0
#
#    ic1    ic2  ic3    ic4    ic5
# 0  392  430.0  466  520.0  21975
# 1  365  415.0  410  473.0  19387
# 2  301  340.0  361  436.0  18837
# 3  401  407.0  399  413.0  14014
# 4  252  280.0  316  348.0  17991

# %%
data[(data["state"]=="FL") & (data["gender"]=='M')]
# Out:
#     controln state gender     hv1 hvp1 pobc1 pobc2    avggift tcode  target_d  \
# 0      44060    FL      M  AAA896    7     6    16  28.000000     1     100.0
# 34     11011    FL      M     559    0    11    20  12.611111  1002      20.0
# 101    37472    FL      M     825    0    63    21  20.000000     1      20.0
# 110   185030    FL      M     824    0    15     7  10.153846     0      10.0
# 137    13239    FL      M    3083   52    26     3   2.916667     1       3.0
# ..       ...   ...    ...     ...  ...   ...   ...        ...   ...       ...
# 948    37747    FL      M    1909   45    32    34  13.375000     1      18.0
# 950    34591    FL      M     835    0     7    20  19.666667     1      23.0
# 969    32622    FL      M     533    4     3    25  23.833333     1      47.0
# 981    43781    FL      M    1069    7     5    15   6.125000     1      10.0
# 997    34475    FL      M     696    2     3    51  20.400000     2      20.0
#
# ...

# %%
data.query('gender=="M" & state=="FL" ')
# Out:
#     controln state gender     hv1 hvp1 pobc1 pobc2    avggift tcode  target_d  \
# 0      44060    FL      M  AAA896    7     6    16  28.000000     1     100.0
# 34     11011    FL      M     559    0    11    20  12.611111  1002      20.0
# 101    37472    FL      M     825    0    63    21  20.000000     1      20.0
# 110   185030    FL      M     824    0    15     7  10.153846     0      10.0
# 137    13239    FL      M    3083   52    26     3   2.916667     1       3.0
# ..       ...   ...    ...     ...  ...   ...   ...        ...   ...       ...
# 948    37747    FL      M    1909   45    32    34  13.375000     1      18.0
# 950    34591    FL      M     835    0     7    20  19.666667     1      23.0
# 969    32622    FL      M     533    4     3    25  23.833333     1      47.0
# 981    43781    FL      M    1069    7     5    15   6.125000     1      10.0
# 997    34475    FL      M     696    2     3    51  20.400000     2      20.0
#
# ...

# %%
data[data['avggift']>15]
# Out:
#     controln state gender      hv1 hvp1 pobc1 pobc2    avggift tcode  \
# 0      44060    FL      M   AAA896    7     6    16  28.000000     1
# 3      21885    NC      M  AAA1095    7     1    74  27.277778     0
# 5     100640    IL      M   764.00    1     2    75  25.571429     1
# 16     31977    FL      F     1513   31     3    24  18.500000     2
# 33    173653    HI      F     2346   67     5    78  15.500000    28
# ..       ...   ...    ...      ...  ...   ...   ...        ...   ...
# 979   188841    NM      F      848    1     6    30  16.000000    28
# 983   130369    CO      F     1017    0     1    47  18.176471    28
# 989   105371    KS    NaN      208    0     0    79  17.176471     0
# 994   149534    CA      F     5000   98    16    42  25.000000    28
# 997    34475    FL      M      696    2     3    51  20.400000     2
#
#      target_d  ic1    ic2  ic3    ic4    ic5
# 0       100.0  392  430.0  466  520.0  21975
# 3        38.0  401  407.0  399  413.0  14014
# ...

# %%
#tempdataset=data.copy()

# %%
file1.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0     44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1     96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2     43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL      F   995.00  252  348.0     0  17991      5      6
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0

# %%
# Standardizing header names

# %%
#Some standards are:
   # use lower case
   # if headers have spaces, replace them with underscores

# %%
cols = []
for i in range(len(data.columns)):
    cols.append(data.columns[i].lower())

# %%
#fixing columns before bringing in to your data frame 
print(file1.columns) # before
cols = []
for i in range(len(file1.columns)):
    cols.append(file1.columns[i].lower().replace(' ', '_'))
file1.columns = cols
print(file1.columns) #after
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')
# Index(['controln', 'state', 'gender', 'hv1', 'ic1', 'ic4', 'hvp1', 'ic5',
#        'pobc1', 'pobc2', 'ic2', 'ic3', 'avggift', 'tcode', 'dob', 'domain',
#        'target_d'],
#       dtype='object')

# %%
data.head()

# %%
data = data.rename(columns={ 'controln':'id','hv1':'median_home_val', 'ic1':'median_household_income'})

# %%
tempdata= data.copy()

# %%
tempdata.head()

# %%
tempdata.dtypes

# %%
tempdata['hv1'] =pd.to_numeric(tempdata['hv1'],errors='coerce')

# %%
tempdata.head()

# %%
data.shape

# %%
data

# %%
data = data.reset_index(drop=True)

# %%
filtered2 = data[(data['gender']== 'M')]

# %%
filtered2.head()

# %%
filtered2= filtered2.reset_index(drop=True)

# %%
filtered2.head()

# %%
filtered2.iloc[2:3,1:3]

# %%
filtered3=filtered2.reset_index().set_index('controln')

# %%
filtered3.head()

# %%
filtered3.iloc[2:10,1:5]

# %%
filtered3.sort_index()

# %%
filtered3.head()

# %%
filtered3.loc[:21885]

# %%
filtered3.iloc[:21885]

# %%
pd.set_option('display.max_rows', 20)

# %%
filtered3.dtypes
# Out:
# index         int64
# state        object
# gender       object
# hv1          object
# hvp1         object
# pobc1        object
# pobc2        object
# avggift     float64
# tcode        object
# target_d    float64
# ic1          object
# ic2         float64
# ic3          object
# ic4         float64
# ic5          object
# dtype: object

# %%
filtered3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 761 entries, 44060 to 123469
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     761 non-null    int64
#  1   state     761 non-null    object
#  2   gender    761 non-null    object
#  3   hv1       760 non-null    object
#  4   hvp1      761 non-null    object
#  5   pobc1     761 non-null    object
#  6   pobc2     761 non-null    object
#  7   avggift   761 non-null    float64
#  8   tcode     761 non-null    object
#  9   target_d  761 non-null    float64
#  10  ic1       761 non-null    object
#  11  ic2       761 non-null    float64
#  12  ic3       761 non-null    object
#  13  ic4       761 non-null    float64
#  14  ic5       761 non-null    object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 115.1+ KB

# %%
round(filtered2.isna().sum()/len(filtered2),4)*100
# Out:
# controln    0.00
# state       0.00
# gender      0.00
# hv1         0.13
# hvp1        0.00
# pobc1       0.00
# pobc2       0.00
# avggift     0.00
# tcode       0.00
# target_d    0.00
# ic1         0.00
# ic2         0.00
# ic3         0.00
# ic4         0.00
# ic5         0.00
# dtype: float64

# %%
nulldf=nulldf.reset_index()

# %%
nulldf.columns = ['header_name', 'percent_nulls']

# %%
nulldf
# Out:
#    header_name  percent_nulls
# 0     controln           0.00
# 1        state           0.00
# 2       gender           0.00
# 3          hv1           0.13
# 4         hvp1           0.00
# 5        pobc1           0.00
# 6        pobc2           0.00
# 7      avggift           0.00
# 8        tcode           0.00
# 9     target_d           0.00
# 10         ic1           0.00
# 11         ic2           0.00
# 12         ic3           0.00
# 13         ic4           0.00
# 14         ic5           0.00

# %%
#filtered2= filtered2.drop(['hv1'], axis =1)

# %%
filtered2[filtered2['hv1'].isna()==True]
# Out:
#     controln state gender  hv1  hvp1  pobc1  pobc2  avggift  tcode  target_d  \
# 13    116894    TX      M  NaN     5      2     42    12.25      1      20.0
#
#     ic1    ic2  ic3    ic4    ic5
# 13  368  457.0  450  531.0  33797

# %%
filtered2.fillna(filtered2.mean())
# Out:
#      controln state gender      hv1  hvp1  pobc1  pobc2    avggift  tcode  \
# 0       44060    FL      M   AAA896     7      6     16  28.000000      1
# 1       96093    IL      M   537.00     0      1     89   5.666667      0
# 2       21885    NC      M  AAA1095     7      1     74  27.277778      0
# 3      100640    IL      M   764.00     1      2     75  25.571429      1
# 4      119038    TX      M   890.00     0      2     46   6.175000   1002
# ..        ...   ...    ...      ...   ...    ...    ...        ...    ...
# 756     15332    NC      M      723     0      6     47   6.538462      1
# 757     74235    MI      M      473     1      0     94  13.500000      4
# 758    165509    CA      M     2213    77      7     62   4.950000      0
# 759    125986    TX      M      533     1      3     75  13.375000      0
# 760    123469    TX      M      561     1      5     68   5.200000      0
#
#      target_d  ic1    ic2  ic3    ic4    ic5
# ...

# %%
data['gender'].value_counts()
# Out:
# F          982
# M          761
# male        60
# female      46
# U           36
# Female      24
# Male        15
# feamale     15
# J           13
# Name: gender, dtype: int64

# %%
len(data[data['gender'].isna()==True])
# Out:
# 2076

# %%
data.to_csv('siansnewfile.csv')
