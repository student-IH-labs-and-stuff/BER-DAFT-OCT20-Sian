# %%
import pandas as pd

# %%
df=pd.read_excel('flight data.xlsx',index_col=0)
df.head()
#null hypothesis - that average fare did not change between 2000 and 2001 q4
#- post 9/11 change 
#significant change! - % change- abs or ratio, comparing to inflation
#understand if this is population or sample data 
# look for other indicators 
# no of passengers - no of passengers goes down, price sinks 
#distance - relationship 
# popl - have a relationship 
# whats the expected variation in the data? 
# - inflation , volatility, seasonality, change in passenger no, change in popul (demand), diff in distance, external diff, new or change in routes
# Out:
#           city to  pop city  from 1000s  pop city to 1000s  \
# city from
# ABE           CLE                613.84            2908.44
# ABE           CLT                613.84            1350.24
# ABE           CMH                613.84            1460.24
# ABE           DEN                613.84            2318.36
# ABE           DFW                613.84            4683.01
#
#            distance betw cities m  avg fare dollars 2000 q4  \
# city from
# ABE                         339.0                    322.20
# ABE                         480.0                    250.27
# ABE                         395.0                    259.29
# ABE                        1539.0                    202.77
# ABE                        1308.0                    344.47
#
#            avg weekly passengers 2000 q4  avg fare dollars 2001 q4  \
# city from
# ABE                                23.36                    326.70
# ABE                                52.60                    241.53
# ...

# %%
stats = df.describe(include='all')
print (stats)
# Out:
#        city to  pop city  from 1000s  pop city to 1000s  \
# count     4175           4175.000000        4175.000000
# unique     184                   NaN                NaN
# top        IAD                   NaN                NaN
# freq       148                   NaN                NaN
# mean       NaN           2374.735272        2553.425013
# std        NaN           3307.832747        3737.031552
# min        NaN             14.870000          18.250000
# 25%        NaN            503.950000         611.810000
# 50%        NaN           1164.720000        1460.240000
# 75%        NaN           2792.140000        2722.650000
# max        NaN          19876.490000       19876.490000
#
#         distance betw cities m  avg fare dollars 2000 q4  \
# count              4175.000000               4175.000000
# unique                     NaN                       NaN
# top                        NaN                       NaN
# freq                       NaN                       NaN
# ...
